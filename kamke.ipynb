# %%
import os
os.environ["USE_SYMENGINE"] = "0"

from sympy.core.backend import *
from delierium.matrix_order import Context, Mgrlex, Mgrevlex, Mlex
from delierium.JanetBasis import Janet_Basis, LHDP
from delierium.Infinitesimals import Janet_Basis_from_ODE
from delierium.helpers import ltf, make_infinitesimal
from  test_kamke import *

# %%
def run_kamke(ode):
    independents = [x]
    dependents = [y(x)]

    infinitesimals = {
        x: make_infinitesimal(x, x, y(x), name="X"),
        y: make_infinitesimal(y(x), x, y(x), name="Y"),
    }
    print(ode)
    jb = Janet_Basis_from_ODE(ode, [y], [x], infinitesimals=infinitesimals)
    print(jb)

for i in Kamke.chapter_1:
    run_kamke(Kamke.chapter_1[i])
# Out:
# Derivative(y(x), x) - 1/sqrt(a0 + a1*x + a2*x**2 + a3*x**3 + a4*x**4)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      11     print(jb)
#      13 for i in Kamke.chapter_1:
# ---> 14     run_kamke(Kamke.chapter_1[i])
#
# Cell In[2], line 10, in run_kamke(ode)
#       5 infinitesimals = {
#       6     x: make_infinitesimal(x, x, y(x), name="X"),
#       7     y: make_infinitesimal(y(x), x, y(x), name="Y"),
#       8 }
#       9 print(ode)
# ---> 10 jb = Janet_Basis_from_ODE(ode, [y], [x], infinitesimals=infinitesimals)
#      11 print(jb)
#
# File ~/research-disk/delierium/src/delierium/Infinitesimals.py:253, in Janet_Basis_from_ODE(ode, dependent, independent, order, *args, **kw)
#     252 def Janet_Basis_from_ODE(ode, dependent, independent, order = "Mgrevlex", *args, **kw):
# --> 253     overdetermined_system = overdeterminedSystemODE(ode, dependent, independent, infinitesimals=kw["infinitesimals"])
#     254     Y = sp.Symbol("D")
#     256     _dependent = dependent[0]
#
# File ~/research-disk/delierium/src/delierium/Infinitesimals.py:250, in overdeterminedSystemODE(ode, dependent, independent, infinitesimals, *args, **kw)
#     245 def overdeterminedSystemODE (ode,
#     246                        dependent,
#     247                        independent,
#     248                        infinitesimals=None
#     249                        , *args, **kw):
# --> 250     return compute_overdetermined_system_of_infinitesimals(ode, dependent, independent, infinitesimals=infinitesimals)
#
# File ~/research-disk/delierium/src/delierium/Infinitesimals.py:200, in compute_overdetermined_system_of_infinitesimals(eq, dep, indep, infinitesimals)
#     197 dummies = {}
#     199 for comb in combos:
# --> 200     funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     201     infinitesimals[funcs[0]] = etas[0]
#     202     dummies[funcs[0]] = sp.Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#
# File ~/research-disk/delierium/src/delierium/Infinitesimals.py:89, in compute_level(deriv_vars_order, dep, indep, infinitesimals)
#      85     funcs, etas = compute_level(prev_order, dep, indep, infinitesimals)
#      86 # Compute current derivatives and infinitesimals functionally
#      87 results = [
#      88             (
# ---> 89                 func_diff(func, v),
#      90                 reduce(
#      91                     lambda acc, var: acc - func_diff(func, var)
#      92                     * func_diff(infinitesimals[var], v),
#      93                     indep,
#      94                     func_diff(eta, v)
#      95                 )
#      96             )
#      97             for func, eta in zip(funcs, etas)
#      98         ]
#      99 # Split result into separate lists
#     100 funcs_next, etas_next = zip(*results)
#
# File ~/research-disk/delierium/src/delierium/Infinitesimals.py:70, in func_diff(fun, var)
#      68     r = fun.xreplace({var: d}).diff(d).xreplace({d: var}).doit()
#      69 else:
# ---> 70     r = sp.Derivative(fun, var).doit()
#      71 return r
#
# File ~/research-disk/delierium/.venv/lib/python3.13/site-packages/sympy/core/function.py:1263, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1261 expr = sympify(expr)
#    1262 if not isinstance(expr, Basic):
# -> 1263     raise TypeError(f"Cannot represent derivative of {type(expr)}")
#    1264 symbols_or_none = getattr(expr, "free_symbols", None)
#    1265 has_symbol_set = isinstance(symbols_or_none, set)
#
# TypeError: Cannot represent derivative of <class 'sympy.core.function.UndefinedFunction'>
