# %%
from sympy import *
from IPython.core.debugger import set_trace
from functools import cache

# %%
import symengine

# %%
x,y=symbols('x, y')

# %%
f=Function('f')(x)

# %%
X=Function('X')(f, x)

# %%
d=Derivative(X, f, x,f,6, x);d.expand()
# Out:
# Derivative(X(f(x), x), f(x), x, (f(x), 6), x)

# %%
def order_of_expression(e, dependent, independent):
    return max([i.args[1][1] for i in preorder_traversal(e)
                if i.is_Derivative and 
                i.args[0] == dependent], default=1)

# %%
order_of_expression(x**2*Derivative(f,x,3), f, x)
# Out:
# 3

# %%
order_of_expression(x**2*f.diff(x,3), f, x)
# Out:
# 3

# %%
y=Function('y')(x)

# %%
f=Function('f')(x,y)

# %%
f.diff(x)
# Out:
# Derivative(f(x, y(x)), y(x))*Derivative(y(x), x) + Subs(Derivative(f(_xi_1, y(x)), _xi_1), _xi_1, x)

# %%
xi=Function('\U000003BE')(x,y);xi
eta=Function('\U000003AE')(x,y);eta
# Out:
# ή(x, y(x))

# %%
dummy=Function('dummy')(x,y)
U=xi*Derivative(dummy,x)+eta*Derivative(dummy, y)

# %%
U
# Out:
# ή(x, y(x))*Derivative(dummy(x, y(x)), y(x)) + ξ(x, y(x))*Derivative(dummy(x, y(x)), x)

# %%
def prolongation(n):
    x = symbols('x')
    y = Function('y')(x)
    X=Function('X')(x, y)

    def Dt(order):        
        #set_trace()
        res = [Derivative(X , x)]
        for i in range(1, order+1):
            g1 = Derivative(y, x, i)
            g2 = Derivative(X, y.diff(x, i), i-1)
            print(f"{g1=}")
            print(f"{g2=}")
            res.append(g1*g2)
        print(f"{sum(res)=}")
        return sum(res)
    def my_zeta(n):
        print(Dt(n))
        if n == 1:
            return Dt(n+1).subs({X:eta}) - diff(y, x)*Dt(n).subs({X:xi})
        return (Dt(n).subs({X: Dt(n-1).subs({X: my_zeta(n-1)})}) - 
             diff(y,x,n) * Dt(n).subs({X:xi}))
    return my_zeta(n)*Derivative(X, diff(y,x,n))

# %%
prolongation(2)
# Out:
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# g1=Derivative(y(x), (x, 2))
# g2=Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x) + Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))*Derivative(y(x), (x, 2))
# X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x) + Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))*Derivative(y(x), (x, 2))
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# g1=Derivative(y(x), (x, 2))
# g2=Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x) + Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))*Derivative(y(x), (x, 2))
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x)
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x)
# X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x)
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# g1=Derivative(y(x), (x, 2))
# g2=Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x) + Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))*Derivative(y(x), (x, 2))
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x)
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# g1=Derivative(y(x), (x, 2))
# g2=Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x) + Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))*Derivative(y(x), (x, 2))
# (((-(ξ(x, y(x))*Derivative(y(x), x) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), x) + ή(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ή(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ή(x, y(x)), x))*Derivative(y(x), x) + Derivative(-(ξ(x, y(x))*Derivative(y(x), x) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), x) + ή(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ή(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ή(x, y(x)), x), x))*Derivative(y(x), x) - (ξ(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ξ(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), (x, 2)) + Derivative((-(ξ(x, y(x))*Derivative(y(x), x) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), x) + ή(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ή(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ή(x, y(x)), x))*Derivative(y(x), x) + Derivative(-(ξ(x, y(x))*Derivative(y(x), x) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), x) + ή(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ή(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ή(x, y(x)), x), x), x) + Derivative((-(ξ(x, y(x))*Derivative(y(x), x) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), x) + ή(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ή(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ή(x, y(x)), x))*Derivative(y(x), x) + Derivative(-(ξ(x, y(x))*Derivative(y(x), x) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), x) + ή(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ή(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ή(x, y(x)), x), x), Derivative(y(x), (x, 2)))*Derivative(y(x), (x, 2)))*Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))

# %%
ff=Function('ff')(x,y,diff(y,x),diff(y,x,2))

# %%
ff
# Out:
# ff(x, y(x), Derivative(y(x), x), Derivative(y(x), (x, 2)))

# %%
f2=diff(ff, diff(y,x,2));f2
# Out:
# Derivative(ff(x, y(x), Derivative(y(x), x), Derivative(y(x), (x, 2))), Derivative(y(x), (x, 2)))

# %%
ff3=f2.subs({y: x**2});ff3
# Out:
# Subs(Derivative(ff(x, x**2, Derivative(x**2, x), _xi_0), _xi_0), _xi_0, Derivative(x**2, (x, 2)))

# %%
prolongation(1)
# Out:
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x)
# X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x)
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# g1=Derivative(y(x), (x, 2))
# g2=Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x) + Derivative(X(x, y(x)), Derivative(y(x), (x, 2)))*Derivative(y(x), (x, 2))
# g1=Derivative(y(x), x)
# g2=X(x, y(x))
# sum(res)=X(x, y(x))*Derivative(y(x), x) + Derivative(X(x, y(x)), x)
# (-(ξ(x, y(x))*Derivative(y(x), x) + Derivative(ξ(x, y(x)), x))*Derivative(y(x), x) + ή(x, y(x))*Derivative(y(x), x) + Derivative(y(x), (x, 2))*Derivative(ή(x, y(x)), Derivative(y(x), (x, 2))) + Derivative(ή(x, y(x)), x))*Derivative(X(x, y(x)), Derivative(y(x), x))
