# %%
plot3d(lambda x, y: 4*x - y, (-1,1), (-1,1))
# Out:
# Graphics3d Object

# %%
plot3d(lambda x, y: 3*(x**3)*(y**2) - 2*x** - 6*(y**2) + 5 , (-1,1), (-1,1), adaptive=True, initial_depth=5)
# Out:
# Graphics3d Object
