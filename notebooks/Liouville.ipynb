# %%
# Baumann  10.5.1
from sympy import *
x, y, z = symbols("x y z")

u = Function('u')(x, y, z)
liouville = diff(u, x, x) + diff(u, y, y) + diff(exp(u), z, z)

# %%
display(liouville)

# %%
from delierium.Infinitesimals import overdetermined_system_pde

# %%
overdetermined_system_pde(liouville, [u], [x, y, z])
