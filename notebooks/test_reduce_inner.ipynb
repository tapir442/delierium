# %%
from delierium.Infinitesimals import prolongationODE, overdeterminedSystemODE
from delierium.helpers import latexer
from delierium.JanetBasis import Janet_Basis, reduceS, _Differential_Polynomial
from delierium.MatrixOrder import Context
from sage.all import *
from IPython.core.debugger import set_trace
from IPython.display import Math

# %%
x, y = var("x y")
z = function("z")(x,y)
w = function("w")(x,y)
ctx = Context([w, z], [x,y])
f4 = _Differential_Polynomial(diff(w, x,  y)+ diff(z, x, y) + diff(w, y)/(2*y) - diff(w, x)/y + x*diff(z, y)/y - w/(2*y**2), ctx)
f1 = _Differential_Polynomial(diff(w,y) + x*diff(z,y)/(2*y*(x**2 +y)) - w/y, ctx)
f2 = _Differential_Polynomial(diff(z,x, y) + y*diff(w,y)/x + 2*y*diff(z, x)/x, ctx)
r = reduceS(f4, [f1, f2], ctx)
# Out:
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(319)reduceS()
#     317             from IPython.core.debugger import set_trace;
#     318             set_trace();
# --> 319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
#     321             if enew == e:
# ipdb>  print(e, dp)
# diff(w(x, y), x, y) + diff(z(x, y), x, y) + (-1/y) * diff(w(x, y), x) + (1/2/y) * diff(w(x, y), y) + (x/y) * diff(z(x, y), y) + (-1/2/y^2) * w(x, y) diff(w(x, y), y) + (1/2*x/((x^2 + y)*y)) * diff(z(x, y), y) + (-1/y) * w(x, y)
# ipdb>  print(e)
# diff(w(x, y), x, y) + diff(z(x, y), x, y) + (-1/y) * diff(w(x, y), x) + (1/2/y) * diff(w(x, y), y) + (x/y) * diff(z(x, y), y) + (-1/2/y^2) * w(x, y)
# ipdb>  print(dp)
# diff(w(x, y), y) + (1/2*x/((x^2 + y)*y)) * diff(z(x, y), y) + (-1/y) * w(x, y)
# ipdb>  s
# --Call--
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(361)reduce()
#     359
#     360
# --> 361 def reduce(e1: _Differential_Polynomial,
#     362            e2: _Differential_Polynomial,
#     363            context: Context) -> _Differential_Polynomial:
# ipdb>  s
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(385)reduce()
#     383     diff(z(x, y), x) + (1/x) * z(x, y)
#     384     """
# --> 385     while not bool((_e1 := _reduce_inner(e1, e2, context)) == e1):
#     386         e1 = _e1
#     387     return _e1
# ipdb>  s
# --Call--
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(335)_reduce_inner()
#     333
#     334
# --> 335 def _reduce_inner(e1, e2, context):
#     336     e2_order = _order(e2.Lder(), context)
#     337     lf = func(e2.Lder())
# ipdb>  s
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(336)_reduce_inner()
#     334
#     335 def _reduce_inner(e1, e2, context):
# --> 336     e2_order = _order(e2.Lder(), context)
#     337     lf = func(e2.Lder())
#     338     for t in (_ for _ in e1._p if eq(func(_._d), lf)):
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(337)_reduce_inner()
#     335 def _reduce_inner(e1, e2, context):
#     336     e2_order = _order(e2.Lder(), context)
# --> 337     lf = func(e2.Lder())
#     338     for t in (_ for _ in e1._p if eq(func(_._d), lf)):
#     339         # S1 from Algorithm 2.4
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(338)_reduce_inner()
#     336     e2_order = _order(e2.Lder(), context)
#     337     lf = func(e2.Lder())
# --> 338     for t in (_ for _ in e1._p if eq(func(_._d), lf)):
#     339         # S1 from Algorithm 2.4
#     340         c = t._coeff
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(340)_reduce_inner()
#     338     for t in (_ for _ in e1._p if eq(func(_._d), lf)):
#     339         # S1 from Algorithm 2.4
# --> 340         c = t._coeff
#     341         e1_order = _order(t._d, context)
#     342         dif = [a-b for a, b in zip(e1_order, e2_order)]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(341)_reduce_inner()
#     339         # S1 from Algorithm 2.4
#     340         c = t._coeff
# --> 341         e1_order = _order(t._d, context)
#     342         dif = [a-b for a, b in zip(e1_order, e2_order)]
#     343         if all(map(lambda h: h == 0, dif)):
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(342)_reduce_inner()
#     340         c = t._coeff
#     341         e1_order = _order(t._d, context)
# --> 342         dif = [a-b for a, b in zip(e1_order, e2_order)]
#     343         if all(map(lambda h: h == 0, dif)):
#     344             # S2 from Algorithm 2.4
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(343)_reduce_inner()
#     341         e1_order = _order(t._d, context)
#     342         dif = [a-b for a, b in zip(e1_order, e2_order)]
# --> 343         if all(map(lambda h: h == 0, dif)):
#     344             # S2 from Algorithm 2.4
#     345             return _Differential_Polynomial(
# ipdb>  pp dif
# [1, 0]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(347)_reduce_inner()
#     345             return _Differential_Polynomial(
#     346                 e1.expression() - e2.expression() * c, context)
# --> 347         if all(map(lambda h: h >= 0, dif)):
#     348             # S2 from Algorithm 2.4
#     349             # toDo: as diff also accepts zerozh derivatives we may
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(351)_reduce_inner()
#     349             # toDo: as diff also accepts zerozh derivatives we may
#     350             # unfy these two branches
# --> 351             variables_to_diff = []
#     352             for i in range(len(context._independent)):
#     353                 if dif[i] != 0:
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(352)_reduce_inner()
#     350             # unfy these two branches
#     351             variables_to_diff = []
# --> 352             for i in range(len(context._independent)):
#     353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(353)_reduce_inner()
#     351             variables_to_diff = []
#     352             for i in range(len(context._independent)):
# --> 353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
#     355             return _Differential_Polynomial(
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(354)_reduce_inner()
#     352             for i in range(len(context._independent)):
#     353                 if dif[i] != 0:
# --> 354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
#     355             return _Differential_Polynomial(
#     356                 e1.expression() - c*diff(e2.expression(), *variables_to_diff),
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(352)_reduce_inner()
#     350             # unfy these two branches
#     351             variables_to_diff = []
# --> 352             for i in range(len(context._independent)):
#     353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(353)_reduce_inner()
#     351             variables_to_diff = []
#     352             for i in range(len(context._independent)):
# --> 353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
#     355             return _Differential_Polynomial(
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(352)_reduce_inner()
#     350             # unfy these two branches
#     351             variables_to_diff = []
# --> 352             for i in range(len(context._independent)):
#     353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(355)_reduce_inner()
#     353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
# --> 355             return _Differential_Polynomial(
#     356                 e1.expression() - c*diff(e2.expression(), *variables_to_diff),
#     357                 context)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(356)_reduce_inner()
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
#     355             return _Differential_Polynomial(
# --> 356                 e1.expression() - c*diff(e2.expression(), *variables_to_diff),
#     357                 context)
#     358     return e1
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(357)_reduce_inner()
#     355             return _Differential_Polynomial(
#     356                 e1.expression() - c*diff(e2.expression(), *variables_to_diff),
# --> 357                 context)
#     358     return e1
#     359
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(355)_reduce_inner()
#     353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
# --> 355             return _Differential_Polynomial(
#     356                 e1.expression() - c*diff(e2.expression(), *variables_to_diff),
#     357                 context)
# ipdb>  n
# --Return--
# <delierium.Ja...x7f32967fd0d0>
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(355)_reduce_inner()
#     353                 if dif[i] != 0:
#     354                     variables_to_diff.extend([context._independent[i]]*abs(dif[i]))
# --> 355             return _Differential_Polynomial(
#     356                 e1.expression() - c*diff(e2.expression(), *variables_to_diff),
#     357                 context)
# ipdb>  n
# --Call--
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(233)__eq__()
#     231         return self._p[0] < other._p[0]
#     232
# --> 233     def __eq__(self, other):
#     234         return all(eq(_[0]._d, _[1]._d) for _ in zip(self._p, other._p))
#     235
# ipdb>  print(self)
# diff(z(x, y), x, y) + (-1/(y*(x/((x^2 + y)*y) - 2))) * diff(w(x, y), y) + (-(2*x/y + 2*x^2/((x^4 + 2*x^2*y + y^2)*y) - 1/((x^2 + y)*y))/(x/((x^2 + y)*y) - 2)) * diff(z(x, y), y) + (1/(y^2*(x/((x^2 + y)*y) - 2))) * w(x, y)
# ipdb>  print(other)
# diff(w(x, y), x, y) + diff(z(x, y), x, y) + (-1/y) * diff(w(x, y), x) + (1/2/y) * diff(w(x, y), y) + (x/y) * diff(z(x, y), y) + (-1/2/y^2) * w(x, y)
# ipdb>  self.show()
# 'z_{x, y}-\\frac{1}{y {\\left(\\frac{x}{{\\left(x^{2} + y\\right)} y} - 2\\right)}} w_{y}-\\frac{\\frac{2 \\, x}{y} + \\frac{2 \\, x^{2}}{{\\left(x^{4} + 2 \\, x^{2} y + y^{2}\\right)} y} - \\frac{1}{{\\left(x^{2} + y\\right)} y}}{\\frac{x}{{\\left(x^{2} + y\\right)} y} - 2} z_{y} + \\frac{1}{y^{2} {\\left(\\frac{x}{{\\left(x^{2} + y\\right)} y} - 2\\right)}} w'
# ipdb>  Display(Math(latexer(self)))
# *** NameError: name 'Display' is not defined
# ipdb>  display(Math(latexer(self)))
# display (Math(latexer(self))): ** raised NameError: name 'Math' is not defined **
# ipdb>  print(latexer(self))
# *** AttributeError: '_Differential_Polynomial' object has no attribute 'expand'
# ipdb>  self.expression()
# -(2*x/y + 2*x^2/((x^4 + 2*x^2*y + y^2)*y) - 1/((x^2 + y)*y))*diff(z(x, y), y)/(x/((x^2 + y)*y) - 2) - diff(w(x, y), y)/(y*(x/((x^2 + y)*y) - 2)) + w(x, y)/(y^2*(x/((x^2 + y)*y) - 2)) + diff(z(x, y), x, y)
# ipdb>  self.expression().expand()
# -2*x*diff(z(x, y), y)/(y*(x/((x^2 + y)*y) - 2)) - 2*x^2*diff(z(x, y), y)/((x^4 + 2*x^2*y + y^2)*y*(x/((x^2 + y)*y) - 2)) - diff(w(x, y), y)/(y*(x/((x^2 + y)*y) - 2)) + w(x, y)/(y^2*(x/((x^2 + y)*y) - 2)) + diff(z(x, y), y)/((x^2 + y)*y*(x/((x^2 + y)*y) - 2)) + diff(z(x, y), x, y)
# ipdb>  self.expression().expand().simplify()
# -2*x*diff(z(x, y), y)/(y*(x/((x^2 + y)*y) - 2)) - 2*x^2*diff(z(x, y), y)/((x^4 + 2*x^2*y + y^2)*y*(x/((x^2 + y)*y) - 2)) - diff(w(x, y), y)/(y*(x/((x^2 + y)*y) - 2)) + w(x, y)/(y^2*(x/((x^2 + y)*y) - 2)) + diff(z(x, y), y)/((x^2 + y)*y*(x/((x^2 + y)*y) - 2)) + diff(z(x, y), x, y)
# ipdb>  self.expression().expand().simplify_full()
# -(x^4*w(x, y) - 2*y^4*diff(z(x, y), x, y) - (4*x^2*diff(z(x, y), x, y) + 2*x*diff(z(x, y), y) + diff(w(x, y), y))*y^3 - (2*x^2*diff(w(x, y), y) + (2*x^4 - x)*diff(z(x, y), x, y) + (4*x^3 - 1)*diff(z(x, y), y) - w(x, y))*y^2 - (x^4*diff(w(x, y), y) - x^3*diff(z(x, y), x, y) - 2*x^2*w(x, y) + (2*x^5 + x^2)*diff(z(x, y), y))*y)/(4*x^2*y^3 - x^3*y + 2*y^4 + (2*x^4 - x)*y^2)
# ipdb>  self.expression()
# -(2*x/y + 2*x^2/((x^4 + 2*x^2*y + y^2)*y) - 1/((x^2 + y)*y))*diff(z(x, y), y)/(x/((x^2 + y)*y) - 2) - diff(w(x, y), y)/(y*(x/((x^2 + y)*y) - 2)) + w(x, y)/(y^2*(x/((x^2 + y)*y) - 2)) + diff(z(x, y), x, y)
# ipdb>  self._p[0]
# <delierium.JanetBasis._Dterm object at 0x7f329647ce50>
# ipdb>  str(self._p[0])
# 'diff(z(x, y), x, y)'
# ipdb>  str(self._p[1])
# '(-1/(y*(x/((x^2 + y)*y) - 2))) * diff(w(x, y), y)'
# ipdb>  str(self._p[1].coeff)
# *** AttributeError: '_Dterm' object has no attribute 'coeff'
# ipdb>  str(self._p[1]._coeff)
# '-1/(y*(x/((x^2 + y)*y) - 2))'
# ipdb>  self._p[1]._coeff
# -1/(y*(x/((x^2 + y)*y) - 2))
# ipdb>  self._p[1]._coeff.expand()
# -1/(y*(x/((x^2 + y)*y) - 2))
# ipdb>  self._p[1]._coeff.simplify()
# -1/(y*(x/((x^2 + y)*y) - 2))
# ipdb>  self._p[1]._coeff.simplify_full()
# (x^2 + y)/(2*x^2*y + 2*y^2 - x)
# ipdb>  self._p[2]._coeff.simplify_full()
# (2*x^5 + 2*x*y^2 + x^2 + (4*x^3 - 1)*y)/(4*x^2*y^2 - x^3 + 2*y^3 + (2*x^4 - x)*y)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(234)__eq__()
#     232
#     233     def __eq__(self, other):
# --> 234         return all(eq(_[0]._d, _[1]._d) for _ in zip(self._p, other._p))
#     235
#     236     def show(self, rich=True):
# ipdb>  n
# --Return--
# False
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(234)__eq__()
#     232
#     233     def __eq__(self, other):
# --> 234         return all(eq(_[0]._d, _[1]._d) for _ in zip(self._p, other._p))
#     235
#     236     def show(self, rich=True):
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(386)reduce()
#     384     """
#     385     while not bool((_e1 := _reduce_inner(e1, e2, context)) == e1):
# --> 386         e1 = _e1
#     387     return _e1
#     388
# ipdb>  c
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(319)reduceS()
#     317             from IPython.core.debugger import set_trace;
#     318             set_trace();
# --> 319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
#     321             if enew == e:
# ipdb>  print(e)
# diff(z(x, y), x, y) + (-2*x/(y*(x/((x^2 + y)*y) - 2)) - 2*x^2/((x^4 + 2*x^2*y + y^2)*y*(x/((x^2 + y)*y) - 2)) + 1/2*x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)) + 1/((x^2 + y)*y*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y)
# ipdb>  print(e, dp)
# diff(z(x, y), x, y) + (-2*x/(y*(x/((x^2 + y)*y) - 2)) - 2*x^2/((x^4 + 2*x^2*y + y^2)*y*(x/((x^2 + y)*y) - 2)) + 1/2*x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)) + 1/((x^2 + y)*y*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y) diff(z(x, y), x, y) + (y/x) * diff(w(x, y), y) + (2*y/x) * diff(z(x, y), x)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(321)reduceS()
#     319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
# --> 321             if enew == e:
#     322                 reducing = False
#     323             else:
# ipdb>  pp enew
# <delierium.JanetBasis._Differential_Polynomial object at 0x7f32975968d0>
# ipdb>  print(enew)
# diff(w(x, y), y) + (2) * diff(z(x, y), x) + (2*x^2/(y^2*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y)
# ipdb>  print(e)
# diff(z(x, y), x, y) + (-2*x/(y*(x/((x^2 + y)*y) - 2)) - 2*x^2/((x^4 + 2*x^2*y + y^2)*y*(x/((x^2 + y)*y) - 2)) + 1/2*x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)) + 1/((x^2 + y)*y*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y)
# ipdb>  enew.__class__
# <class 'delierium.JanetBasis._Differential_Polynomial'>
# ipdb>  enew_.p[0]
# *** NameError: name 'enew_' is not defined
# ipdb>  enew._p[0]
# <delierium.JanetBasis._Dterm object at 0x7f329647f810>
# ipdb>  print(enew._p[0])
# diff(w(x, y), y)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(324)reduceS()
#     322                 reducing = False
#     323             else:
# --> 324                 e = enew
#     325                 gen = (_ for _ in S)
#     326                 reducing = True
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(325)reduceS()
#     323             else:
#     324                 e = enew
# --> 325                 gen = (_ for _ in S)
#     326                 reducing = True
#     327     return enew
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(326)reduceS()
#     324                 e = enew
#     325                 gen = (_ for _ in S)
# --> 326                 reducing = True
#     327     return enew
#     328
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(316)reduceS()
#     314     gen = (_ for _ in S)
#     315     while reducing:
# --> 316         for dp in gen:
#     317             from IPython.core.debugger import set_trace;
#     318             set_trace();
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(315)reduceS()
#     313     reducing = True
#     314     gen = (_ for _ in S)
# --> 315     while reducing:
#     316         for dp in gen:
#     317             from IPython.core.debugger import set_trace;
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(316)reduceS()
#     314     gen = (_ for _ in S)
#     315     while reducing:
# --> 316         for dp in gen:
#     317             from IPython.core.debugger import set_trace;
#     318             set_trace();
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(317)reduceS()
#     315     while reducing:
#     316         for dp in gen:
# --> 317             from IPython.core.debugger import set_trace;
#     318             set_trace();
#     319             enew = reduce(e, dp, context)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(318)reduceS()
#     316         for dp in gen:
#     317             from IPython.core.debugger import set_trace;
# --> 318             set_trace();
#     319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(319)reduceS()
#     317             from IPython.core.debugger import set_trace;
#     318             set_trace();
# --> 319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
#     321             if enew == e:
# ipdb>  print(e)
# diff(w(x, y), y) + (2) * diff(z(x, y), x) + (2*x^2/(y^2*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y)
# ipdb>  print(dp)
# diff(w(x, y), y) + (1/2*x/((x^2 + y)*y)) * diff(z(x, y), y) + (-1/y) * w(x, y)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(321)reduceS()
#     319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
# --> 321             if enew == e:
#     322                 reducing = False
#     323             else:
# ipdb>  print(enew)
# diff(z(x, y), x) + (-1/4*x/((x^2 + y)*y) + x^2/(y^2*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y) + (1/2/y) * w(x, y)
# ipdb>  enew._p[0]
# <delierium.JanetBasis._Dterm object at 0x7f3296c2abd0>
# ipdb>  print(enew._p[0])
# diff(z(x, y), x)
# ipdb>  c
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(319)reduceS()
#     317             from IPython.core.debugger import set_trace;
#     318             set_trace();
# --> 319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
#     321             if enew == e:
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(321)reduceS()
#     319             enew = reduce(e, dp, context)
#     320             # XXX check wheter we can repalce "==" by 'is'
# --> 321             if enew == e:
#     322                 reducing = False
#     323             else:
# ipdb>  pront(enew)
# *** NameError: name 'pront' is not defined
# ipdb>  print(enew)
# diff(z(x, y), x) + (-1/4*x/((x^2 + y)*y) + x^2/(y^2*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y) + (1/2/y) * w(x, y)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(322)reduceS()
#     320             # XXX check wheter we can repalce "==" by 'is'
#     321             if enew == e:
# --> 322                 reducing = False
#     323             else:
#     324                 e = enew
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(316)reduceS()
#     314     gen = (_ for _ in S)
#     315     while reducing:
# --> 316         for dp in gen:
#     317             from IPython.core.debugger import set_trace;
#     318             set_trace();
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(315)reduceS()
#     313     reducing = True
#     314     gen = (_ for _ in S)
# --> 315     while reducing:
#     316         for dp in gen:
#     317             from IPython.core.debugger import set_trace;
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/JanetBasis.py(327)reduceS()
#     325                 gen = (_ for _ in S)
#     326                 reducing = True
# --> 327     return enew
#     328
#     329 def _order(der, context):
# ipdb>  print(enew)
# diff(z(x, y), x) + (-1/4*x/((x^2 + y)*y) + x^2/(y^2*(x/((x^2 + y)*y) - 2))) * diff(z(x, y), y) + (1/2/y) * w(x, y)
# ipdb>  quit

# %%
print()

# %%
bool(1/2/y ==1/(2*y))
# Out:
# True
