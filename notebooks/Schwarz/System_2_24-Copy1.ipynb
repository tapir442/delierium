# %%
from sage.all import *
from delierium.MatrixOrder import Context, Mgrlex, Mgrevlex, Mlex
from delierium.JanetBasis import Janet_Basis, _Differential_Polynomial
from delierium.helpers import latexer
from IPython.display import Math

vars = var ("x y")
z = function("z")(x,y)
w = function("w")(x,y)
# ctx: items are in descending order
ctx_grevlex_f = Context((w,z), (y,x), Mgrevlex)
ctx_grlex_f   = Context((w,z), (y,x), Mgrlex)
ctx_lex_f     = Context((w,z), (y,x), Mlex)

f1 = diff(w, y) + x*diff(z,y)/(2*y*(x**2+y)) - w/y
f2 = diff(z,x,y) + y*diff(w,y)/x + 2*y*diff(z, x)/x
f3 = diff(w, x,y) - 2*x*diff(z, x,2)/y - x*diff(w,x)/y**2
f4 = diff(w, x,y) + diff(z, x,y) + diff(w, y)/(2*y) - diff(w,x)/y + x* diff(z, y)/y - w/(2*y**2)
f5 = diff(w,y,y) + diff(z,x,y) - diff(w, y)/y + w/(y**2)

dp=_Differential_Polynomial(f4, ctx_grevlex_f)
# Out:
# after creation of DP
# ===> str(_)='diff(w(x, y), x, y)',  (1, 1, 1, 0)
# ===> str(_)='diff(z(x, y), x, y)',  (1, 1, 0, 1)
# ===> str(_)='(1/2/y) * diff(w(x, y), y)',  (1, 0, 1, 0)
# ===> str(_)='(-1/y) * diff(w(x, y), x)',  (0, 1, 1, 0)
# ===> str(_)='(x/y) * diff(z(x, y), y)',  (1, 0, 0, 1)
# ===> str(_)='(-1/2/y^2) * w(x, y)',  (0, 0, 1, 0)

# %%
display(Math(dp.latex()))
# Out:
# $\displaystyle  w_{x,y}+ z_{x,y}+\frac{1}{2 \, y} w_{y}-\frac{1}{y} w_{x}+\frac{x}{y} z_{y}-\frac{1}{2 \, y^{2}} w$

# %%
import os; os.getcwd()
# Out:
# '/home/tapir/research-disk/delierium/notebooks/Schwarz'
