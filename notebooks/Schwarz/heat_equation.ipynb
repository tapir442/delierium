# %%
import os
os.environ["USE_SYMENGINE"] = "1"

from sympy.core.backend import *
from delierium.matrix_order import Context, Mgrlex, Mgrevlex, Mlex
from delierium.JanetBasis import Janet_Basis, LHDP
from delierium.helpers import latexer
from IPython.display import Math

x,t = symbols("x t")
u = Function("u")(x,t)
v = Function("v")(x,t)
# ctx: items are in descending order"
ctx_grevlex_f = Context((u, v), (x,t), Mgrevlex)
ctx_grlex_f   = Context((u, v), (x,t), Mgrlex)
ctx_lex_f     = Context((u, v), (x,t), Mlex)

f1 = diff(v, t)-(u**2+1)*diff(u, x)-u
f2 = diff(u, t) - diff(v,x)
system_2_24 = [f1,f2]
import time

# %%
start=time.time()
jb=Janet_Basis(system_2_24, [u, v], [x,t], Mgrevlex)
print(time.time() - start)
for _ in jb.S:
    display(Math(_.latex()))
#print("======================================")
#start=time.time()
#jb=Janet_Basis(system_2_24, [z,w], [x,y], Mgrlex)
#print(time.time() - start)
#for _ in jb.S:
#    print(_)
#print("======================================")
#start=time.time()
#jb=Janet_Basis(system_2_24, [z,w], [x,y], Mgrevlex)
#print(time.time() - start)
#for _ in jb.S:
#    print(_)    
#print("======================================")
# Out:
# 0.04188251495361328
# $\displaystyle  u_{t}- v_{x}$
# $\displaystyle  u_{x}- \frac{1}{u^{2}{\left(x,t \right)} + 1} v_{t}+\frac{1}{u^{2}{\left(x,t \right)} + 1} u$

# %%
start=time.time()
jb=Janet_Basis(system_2_24, [z,w], [y,x], Mlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [z,w], [y,x], Mgrlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [z,w], [y,x], Mgrevlex)
print(time.time() - start)
for _ in jb.S:
    print(_)    
print("======================================")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 start=time.time()
# ----> 2 jb=Janet_Basis(system_2_24, [z,w], [y,x], Mlex)
#       3 print(time.time() - start)
#       4 for _ in jb.S:
#
# NameError: name 'z' is not defined

# %%
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [y,x], Mlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [y,x], Mgrlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [y,x], Mgrevlex)
print(time.time() - start)
for _ in jb.S:
    print(_)    
print("======================================")

# %%
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [x,y], Mlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("looks strange as len(S) == 3 instead of 4")    
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [x,y], Mgrlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [x,y], Mgrevlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
