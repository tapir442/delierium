# %%
import sympy

# %%
dir(sympy)
# Out:
# ['Abs',
#  'AccumBounds',
#  'Add',
#  'Adjoint',
#  'AlgebraicField',
#  'AlgebraicNumber',
#  'And',
#  'AppliedPredicate',
#  'Array',
#  'AssumptionsContext',
#  'Atom',
#  'AtomicExpr',
#  'BasePolynomialError',
#  'Basic',
#  'BlockDiagMatrix',
#  'BlockMatrix',
#  'CC',
#  'CRootOf',
#  'Catalan',
#  'Chi',
#  'Ci',
#  'Circle',
#  'CoercionFailed',
#  'Complement',
#  'ComplexField',
#  'ComplexRegion',
#  'ComplexRootOf',
#  'Complexes',
#  'ComputationFailed',
#  'ConditionSet',
#  'Contains',
#  'CosineTransform',
#  'Curve',
#  'DeferredVector',
#  'DenseNDimArray',
#  'Derivative',
#  'Determinant',
#  'DiagMatrix',
#  'DiagonalMatrix',
#  'DiagonalOf',
#  'Dict',
#  'DiracDelta',
#  'DisjointUnion',
#  'Domain',
#  'DomainError',
#  'DotProduct',
#  'Dummy',
#  'E',
#  'E1',
#  'EPath',
#  'EX',
#  'EXRAW',
#  'Ei',
#  'Eijk',
#  'Ellipse',
#  'EmptySequence',
#  'EmptySet',
#  'Eq',
#  'Equality',
#  'Equivalent',
#  'EulerGamma',
#  'EvaluationFailed',
# ...

# %%
var('A B a alpha b beta m n x ')
A.add(2, method='giac')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 var('A B a alpha b beta m n x ')
# ----> 2 A.add(Integer(2), method='giac')
#
# File ~/mambaforge/envs/sage/lib/python3.11/site-packages/sage/symbolic/expression.pyx:6825, in sage.symbolic.expression.Expression.add (build/cythonized/sage/symbolic/expression.cpp:83232)()
#    6823                 hold))
#    6824
# -> 6825 def add(self, *args, hold=False):
#    6826     """
#    6827     Return the sum of the current expression and the given arguments.
#
# TypeError: add() got an unexpected keyword argument 'method'

# %%
v=giac.add(A, B, x*2)

# %%
v.__class__
# Out:
# <class 'sage.interfaces.giac.GiacElement'>

# %%
dir(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dir(v)
#
# File ~/mambaforge/envs/sage/lib/python3.11/site-packages/sage/structure/element.pyx:543, in sage.structure.element.Element.__dir__ (build/cythonized/sage/structure/element.c:11990)()
#     541         return dir_with_other_class(self, ec)
#     542     else:
# --> 543         return dir_with_other_class(self, ec, mc)
#     544
#     545 def _repr_(self):
#
# File ~/mambaforge/envs/sage/lib/python3.11/site-packages/sage/cpython/getattr.pyx:436, in sage.cpython.getattr.dir_with_other_class (build/cythonized/sage/cpython/getattr.c:5031)()
#     434     ret.update(list(self.__dict__))
#     435 for c in cls:
# --> 436     if not isinstance(self, c):
#     437         ret.update(dir(c))
#     438 return sorted(ret)
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union

# %%
vv=v.sage()

# %%
vv
# Out:
# A + B + 2*x

# %%
vv.__class__
# Out:
# <class 'sage.symbolic.expression.Expression'>

# %%
dir(giac(vv))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dir(giac(vv))
#
# File ~/mambaforge/envs/sage/lib/python3.11/site-packages/sage/structure/element.pyx:543, in sage.structure.element.Element.__dir__ (build/cythonized/sage/structure/element.c:11990)()
#     541         return dir_with_other_class(self, ec)
#     542     else:
# --> 543         return dir_with_other_class(self, ec, mc)
#     544
#     545 def _repr_(self):
#
# File ~/mambaforge/envs/sage/lib/python3.11/site-packages/sage/cpython/getattr.pyx:436, in sage.cpython.getattr.dir_with_other_class (build/cythonized/sage/cpython/getattr.c:5031)()
#     434     ret.update(list(self.__dict__))
#     435 for c in cls:
# --> 436     if not isinstance(self, c):
#     437         ret.update(dir(c))
#     438 return sorted(ret)
#
# ...

# %%
giac(vv).multiply(4)
# Out:
# 4*(sageVARA+sageVARB+sageVARx*2)
