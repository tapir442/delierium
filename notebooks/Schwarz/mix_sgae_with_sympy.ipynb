# %%
from IPython.core.debugger import set_trace 
import sympy.core.backend 
be_diff=sympy.core.backend.diff
print(diff, diff.__class__)
print(be_diff, be_diff.__class__)
# Out:
# <function derivative at 0x7309da07cd60> <class 'function'>
# <function diff at 0x73098e155ee0> <class 'function'>

# %%
x, y = var("x, y")

# %%
r=sqrt((4*x**7*y**2 + 12*x**5*y**3 - 3*x**5*y + 2*x**4*y**2 + x**4 + 12*x**3*y**4 - 8*x**3*y**2 + 2*x**2*y + 4*x*y**5 - 5*x*y**3 - 2*y**4)/(x*y*(2*x**4*y - x**3 + 4*x**2*y**2 - x*y + 2*y**3)))/((log(sqrt(x + y/x))))

# %%
# %timeit k=diff(diff(r, x)**2, y, x)
# %timeit k=be_diff(be_diff(r, x)**2, y, x)
# Out:
# 8.74 ms ± 307 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.58 ms ± 226 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
from importlib import reload
import os
os.environ["USE_SYMENGINE"] = "1"
reload(sympy.core.backend)
be_diff=sympy.core.backend.diff
print(be_diff, be_diff.__class__)
# Out:
# <cyfunction diff at 0x7309898c8930> <class '_cython_3_0_11.cython_function_or_method'>

# %%
# %timeit k=diff(diff(r, x)**2, y, x)
# %timeit k=be_diff(be_diff(r, x)**2, y, x)
# Out:
# 8.9 ms ± 347 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.04 ms ± 343 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
os.environ["USE_SYMENGINE"] = "0"
import sympy.core.backend 
be_diff=sympy.core.backend.diff
print(diff)
print(be_diff)
x,y = sympy.core.backend.symbols("x, y")
print(x, x.__class__)
r=sqrt((4*x**7*y**2 + 12*x**5*y**3 - 3*x**5*y + 2*x**4*y**2 + x**4 + 12*x**3*y**4 - 8*x**3*y**2 + 2*x**2*y + 4*x*y**5 - 5*x*y**3 - 2*y**4)/(x*y*(2*x**4*y - x**3 + 4*x**2*y**2 - x*y + 2*y**3)))/((log(sqrt(x + y/x))))
print(r, r.__class__)
# %timeit k=be_diff(be_diff(sympy.core.backend.sympify(r), x)**2, y, x)
# Out:
# <function derivative at 0x7309da07cd60>
# <cyfunction diff at 0x7309898c8930>
# x <class 'symengine.lib.symengine_wrapper.Symbol'>
# sqrt((4*x^7*y^2 + 12*x^5*y^3 + 12*x^3*y^4 - 3*x^5*y + 2*x^4*y^2 + 4*x*y^5 - 8*x^3*y^2 + x^4 - 5*x*y^3 - 2*y^4 + 2*x^2*y)/((2*x^4*y + 4*x^2*y^2 - x^3 + 2*y^3 - x*y)*x*y))/log(sqrt(x + y/x)) <class 'sage.symbolic.expression.Expression'>
# 4.02 ms ± 341 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
