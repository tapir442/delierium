# %%
from sympy import *
from delierium.Infinitesimals import overdeterminedSystemODE,Janet_Basis_from_ODE
from delierium.matrix_order import Context
from IPython.core.debugger import set_trace
from delierium.helpers import ltf

# %%
# Schwarz, Example_5.17, p.218
x   = Symbol('x')
y   = Function('y')(x)
d0 = y
d1 = diff(d0, x)
d2 = diff(d1, x)
ode = 8*x*d2*d0**6 \
    - 9*x**5*d1**4 \
    - 16*x*d1**2*d0**5 \
    + 16 *d1*d0**6
ltf(ode, [y], [x])
inf=Janet_Basis_from_ODE(ode, y, x)
for _ in inf:
    ltf(_, [y], [x])
# Out:
#      5      4        6                5      2       6
# - 9⋅x ⋅y_{x}  + 8⋅x⋅y ⋅y_{xx} - 16⋅x⋅y ⋅y_{x}  + 16⋅y ⋅y_{x}
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(206)compute_overdetermined_system_of_infinitesimals()
#     204     infinitesimals : dict{Function/Symbol : new name}
#     205     """
# --> 206     from IPython.core.debugger import set_trace; set_trace()
#     207     infinitesimals = create_infinitesimals(dep, indep, infinitesimals)
#     208     eq_order, highest_term = order(eq, dep, indep)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(207)compute_overdetermined_system_of_infinitesimals()
#     205     """
#     206     from IPython.core.debugger import set_trace; set_trace()
# --> 207     infinitesimals = create_infinitesimals(dep, indep, infinitesimals)
#     208     eq_order, highest_term = order(eq, dep, indep)
#     209     highest_term = list(highest_term)[0]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(208)compute_overdetermined_system_of_infinitesimals()
#     206     from IPython.core.debugger import set_trace; set_trace()
#     207     infinitesimals = create_infinitesimals(dep, indep, infinitesimals)
# --> 208     eq_order, highest_term = order(eq, dep, indep)
#     209     highest_term = list(highest_term)[0]
#     210     combos = variable_combinations(indep, eq_order)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(209)compute_overdetermined_system_of_infinitesimals()
#     207     infinitesimals = create_infinitesimals(dep, indep, infinitesimals)
#     208     eq_order, highest_term = order(eq, dep, indep)
# --> 209     highest_term = list(highest_term)[0]
#     210     combos = variable_combinations(indep, eq_order)
#     211     dummies = {}
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(210)compute_overdetermined_system_of_infinitesimals()
#     208     eq_order, highest_term = order(eq, dep, indep)
#     209     highest_term = list(highest_term)[0]
# --> 210     combos = variable_combinations(indep, eq_order)
#     211     dummies = {}
#     212
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(211)compute_overdetermined_system_of_infinitesimals()
#     209     highest_term = list(highest_term)[0]
#     210     combos = variable_combinations(indep, eq_order)
# --> 211     dummies = {}
#     212
#     213     for comb in combos:
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(213)compute_overdetermined_system_of_infinitesimals()
#     211     dummies = {}
#     212
# --> 213     for comb in combos:
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(214)compute_overdetermined_system_of_infinitesimals()
#     212
#     213     for comb in combos:
# --> 214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
#     216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(215)compute_overdetermined_system_of_infinitesimals()
#     213     for comb in combos:
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
# --> 215         infinitesimals[funcs[0]] = etas[0]
#     216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(216)compute_overdetermined_system_of_infinitesimals()
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# --> 216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
#     218     vdummies = {}
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(216)compute_overdetermined_system_of_infinitesimals()
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# --> 216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
#     218     vdummies = {}
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(213)compute_overdetermined_system_of_infinitesimals()
#     211     dummies = {}
#     212
# --> 213     for comb in combos:
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(214)compute_overdetermined_system_of_infinitesimals()
#     212
#     213     for comb in combos:
# --> 214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
#     216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(215)compute_overdetermined_system_of_infinitesimals()
#     213     for comb in combos:
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
# --> 215         infinitesimals[funcs[0]] = etas[0]
#     216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(216)compute_overdetermined_system_of_infinitesimals()
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# --> 216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
#     218     vdummies = {}
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(216)compute_overdetermined_system_of_infinitesimals()
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# --> 216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
#     218     vdummies = {}
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(216)compute_overdetermined_system_of_infinitesimals()
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# --> 216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
#     218     vdummies = {}
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(213)compute_overdetermined_system_of_infinitesimals()
#     211     dummies = {}
#     212
# --> 213     for comb in combos:
#     214         funcs, etas = compute_level(comb, dep, indep, infinitesimals)
#     215         infinitesimals[funcs[0]] = etas[0]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(218)compute_overdetermined_system_of_infinitesimals()
#     216         dummies[funcs[0]] = Symbol(f"{dep[0].name}_{"".join([str(v) for v in comb])}")
#     217
# --> 218     vdummies = {}
#     219     for i in dep + indep:
#     220         vdummies[i] = Symbol(i.name)
# ipdb>  pp dummies
# *** TypeError: cannot determine truth value of Relational: Derivative(y(x), (x, 2)) < Derivative(y(x), x)
# ipdb>  p dummies
# {Derivative(y(x), x): y_x, Derivative(y(x), (x, 2)): y_xx}
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(219)compute_overdetermined_system_of_infinitesimals()
#     217
#     218     vdummies = {}
# --> 219     for i in dep + indep:
#     220         vdummies[i] = Symbol(i.name)
#     221
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(220)compute_overdetermined_system_of_infinitesimals()
#     218     vdummies = {}
#     219     for i in dep + indep:
# --> 220         vdummies[i] = Symbol(i.name)
#     221
#     222     _dummies = ChainMap(dummies, vdummies)
# ipdb>  pp dep, indep
# ([y(x)], [x])
# ipdb>  dep+indep
# [y(x), x]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(219)compute_overdetermined_system_of_infinitesimals()
#     217
#     218     vdummies = {}
# --> 219     for i in dep + indep:
#     220         vdummies[i] = Symbol(i.name)
#     221
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(220)compute_overdetermined_system_of_infinitesimals()
#     218     vdummies = {}
#     219     for i in dep + indep:
# --> 220         vdummies[i] = Symbol(i.name)
#     221
#     222     _dummies = ChainMap(dummies, vdummies)
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(219)compute_overdetermined_system_of_infinitesimals()
#     217
#     218     vdummies = {}
# --> 219     for i in dep + indep:
#     220         vdummies[i] = Symbol(i.name)
#     221
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(222)compute_overdetermined_system_of_infinitesimals()
#     220         vdummies[i] = Symbol(i.name)
#     221
# --> 222     _dummies = ChainMap(dummies, vdummies)
#     223     r = prolongation(eq, eq_order, infinitesimals, dep, indep, _dummies)
#     224     sol = solve(eq, highest_term)[0]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(223)compute_overdetermined_system_of_infinitesimals()
#     221
#     222     _dummies = ChainMap(dummies, vdummies)
# --> 223     r = prolongation(eq, eq_order, infinitesimals, dep, indep, _dummies)
#     224     sol = solve(eq, highest_term)[0]
#     225     r = r.xreplace(finish_substitution(r))
# ipdb>  p _dummies
# ChainMap({Derivative(y(x), x): y_x, Derivative(y(x), (x, 2)): y_xx}, {y(x): y, x: x})
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(224)compute_overdetermined_system_of_infinitesimals()
#     222     _dummies = ChainMap(dummies, vdummies)
#     223     r = prolongation(eq, eq_order, infinitesimals, dep, indep, _dummies)
# --> 224     sol = solve(eq, highest_term)[0]
#     225     r = r.xreplace(finish_substitution(r))
#     226     r = r.xreplace({highest_term: sol})
# ipdb>  pp r
# 8*x*((Derivative(Y(y(x), x), (y(x), 2))*Derivative(y(x), x) + Derivative(Y(y(x), x), y(x), x))*Derivative(y(x), x) - 2*(Derivative(X(y(x), x), x) + Derivative(X(y(x), x), y(x))*Derivative(y(x), x))*Derivative(y(x), (x, 2)) - ((Derivative(X(y(x), x), (y(x), 2))*Derivative(y(x), x) + Derivative(X(y(x), x), y(x), x))*Derivative(y(x), x) + Derivative(X(y(x), x), (x, 2)) + Derivative(X(y(x), x), y(x))*Derivative(y(x), (x, 2)) + Derivative(y(x), x)*Derivative(X(y(x), x), x, y(x)))*Derivative(y(x), x) + Derivative(Y(y(x), x), (x, 2)) + Derivative(Y(y(x), x), y(x))*Derivative(y(x), (x, 2)) + Derivative(y(x), x)*Derivative(Y(y(x), x), x, y(x)))*y(x)**6 + (-45*x**4*Derivative(y(x), x)**4 + 8*y(x)**6*Derivative(y(x), (x, 2)) - 16*y(x)**5*Derivative(y(x), x)**2)*X(y(x), x) + (-36*x**5*Derivative(y(x), x)**3 - 32*x*y(x)**5*Derivative(y(x), x) + 16*y(x)**6)*(-(Derivative(X(y(x), x), x) + Derivative(X(y(x), x), y(x))*Derivative(y(x), x))*Derivative(y(x), x) + Derivative(Y(y(x), x), x) + Derivative(Y(y(x), x), y(x))*Derivative(y(x), x)) + (48*x*y(x)**5*Derivative(y(x), (x, 2)) - 80*x*y(x)**4*Derivative(y(x), x)**2 + 96*y(x)**5*Derivative(y(x), x))*Y(y(x), x)
# ipdb>  display(r)
#     ⎛⎛   2                              2               ⎞                      ↪
#     ⎜⎜  d                d             d                ⎟ d            ⎛d      ↪
# 8⋅x⋅⎜⎜──────(Y(y(x), x))⋅──(y(x)) + ────────(Y(y(x), x))⎟⋅──(y(x)) - 2⋅⎜──(X(y ↪
#     ⎜⎜     2             dx         dx dy(x)            ⎟ dx           ⎝dx     ↪
#     ⎝⎝dy(x)                                             ⎠                      ↪
#
# ↪                                         2          ⎛⎛   2                    ↪
# ↪              d               d       ⎞ d           ⎜⎜  d                d    ↪
# ↪ (x), x)) + ─────(X(y(x), x))⋅──(y(x))⎟⋅───(y(x)) - ⎜⎜──────(X(y(x), x))⋅──(y ↪
# ↪            dy(x)             dx      ⎠   2         ⎜⎜     2             dx   ↪
# ↪                                        dx          ⎝⎝dy(x)                   ↪
#
# ↪            2               ⎞             2                                   ↪
# ↪           d                ⎟ d          d                   d                ↪
# ↪ (x)) + ────────(X(y(x), x))⎟⋅──(y(x)) + ───(X(y(x), x)) + ─────(X(y(x), x))⋅ ↪
# ↪        dx dy(x)            ⎟ dx           2               dy(x)              ↪
# ↪                            ⎠            dx                                   ↪
#
# ↪  2                       2               ⎞             2                     ↪
# ↪ d           d           d                ⎟ d          d                   d  ↪
# ↪ ───(y(x)) + ──(y(x))⋅────────(X(y(x), x))⎟⋅──(y(x)) + ───(Y(y(x), x)) + ──── ↪
# ↪   2         dx       dy(x) dx            ⎟ dx           2               dy(x ↪
# ↪ dx                                       ⎠            dx                     ↪
#
# ↪                2                       2               ⎞         ⎛           ↪
# ↪               d           d           d                ⎟  6      ⎜      4 ⎛d ↪
# ↪ ─(Y(y(x), x))⋅───(y(x)) + ──(y(x))⋅────────(Y(y(x), x))⎟⋅y (x) + ⎜- 45⋅x ⋅⎜─ ↪
# ↪ )               2         dx       dy(x) dx            ⎟         ⎜        ⎝d ↪
# ↪               dx                                       ⎠         ⎝           ↪
#
# ↪         4            2                             2⎞              ⎛         ↪
# ↪        ⎞       6    d               5    ⎛d       ⎞ ⎟              ⎜      5  ↪
# ↪ ─(y(x))⎟  + 8⋅y (x)⋅───(y(x)) - 16⋅y (x)⋅⎜──(y(x))⎟ ⎟⋅X(y(x), x) + ⎜- 36⋅x ⋅ ↪
# ↪ x      ⎠              2                  ⎝dx      ⎠ ⎟              ⎝         ↪
# ↪                     dx                              ⎠                        ↪
#
# ↪           3                                 ⎞                                ↪
# ↪ ⎛d       ⎞          5    d              6   ⎟ ⎛  ⎛d                  d       ↪
# ↪ ⎜──(y(x))⎟  - 32⋅x⋅y (x)⋅──(y(x)) + 16⋅y (x)⎟⋅⎜- ⎜──(X(y(x), x)) + ─────(X(y ↪
# ↪ ⎝dx      ⎠               dx                 ⎠ ⎝  ⎝dx               dy(x)     ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪          d       ⎞ d          d                  d               d       ⎞   ↪
# ↪ (x), x))⋅──(y(x))⎟⋅──(y(x)) + ──(Y(y(x), x)) + ─────(Y(y(x), x))⋅──(y(x))⎟ + ↪
# ↪          dx      ⎠ dx         dx               dy(x)             dx      ⎠   ↪
# ↪                                                                              ↪
#
# ↪  ⎛            2                               2                    ⎞         ↪
# ↪  ⎜      5    d                 4    ⎛d       ⎞        5    d       ⎟         ↪
# ↪  ⎜48⋅x⋅y (x)⋅───(y(x)) - 80⋅x⋅y (x)⋅⎜──(y(x))⎟  + 96⋅y (x)⋅──(y(x))⎟⋅Y(y(x), ↪
# ↪  ⎜             2                    ⎝dx      ⎠             dx      ⎟         ↪
# ↪  ⎝           dx                                                    ⎠         ↪
#
# ↪
# ↪
# ↪  x)
# ↪
# ↪
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(225)compute_overdetermined_system_of_infinitesimals()
#     223     r = prolongation(eq, eq_order, infinitesimals, dep, indep, _dummies)
#     224     sol = solve(eq, highest_term)[0]
# --> 225     r = r.xreplace(finish_substitution(r))
#     226     r = r.xreplace({highest_term: sol})
#     227     coeffs = sorted(
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(226)compute_overdetermined_system_of_infinitesimals()
#     224     sol = solve(eq, highest_term)[0]
#     225     r = r.xreplace(finish_substitution(r))
# --> 226     r = r.xreplace({highest_term: sol})
#     227     coeffs = sorted(
#     228         extract_coeffs(r, dep, indep),
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(227)compute_overdetermined_system_of_infinitesimals()
#     225     r = r.xreplace(finish_substitution(r))
#     226     r = r.xreplace({highest_term: sol})
# --> 227     coeffs = sorted(
#     228         extract_coeffs(r, dep, indep),
#     229         key=get_coeff_order,
# ipdb>  display(r)
#     ⎛                                                                          ↪
#     ⎜                                                                          ↪
#     ⎜⎛   2                              2               ⎞                      ↪
#     ⎜⎜  d                d             d                ⎟ d            ⎛d      ↪
# 8⋅x⋅⎜⎜──────(Y(y(x), x))⋅──(y(x)) + ────────(Y(y(x), x))⎟⋅──(y(x)) - 2⋅⎜──(X(y ↪
#     ⎜⎜     2             dx         dx dy(x)            ⎟ dx           ⎝dx     ↪
#     ⎝⎝dy(x)                                             ⎠                      ↪
#
# ↪                                        ⎛               4               2     ↪
# ↪                                        ⎜   4 ⎛d       ⎞      ⎛d       ⎞      ↪
# ↪                                        ⎜9⋅x ⋅⎜──(y(x))⎟    2⋅⎜──(y(x))⎟    2 ↪
# ↪              d               d       ⎞ ⎜     ⎝dx      ⎠      ⎝dx      ⎠      ↪
# ↪ (x), x)) + ─────(X(y(x), x))⋅──(y(x))⎟⋅⎜──────────────── + ───────────── - ─ ↪
# ↪            dy(x)             dx      ⎠ ⎜       6               y(x)          ↪
# ↪                                        ⎝    8⋅y (x)                          ↪
#
# ↪          ⎞   ⎛               4               2             ⎞                 ↪
# ↪  d       ⎟   ⎜   4 ⎛d       ⎞      ⎛d       ⎞      d       ⎟                 ↪
# ↪ ⋅──(y(x))⎟   ⎜9⋅x ⋅⎜──(y(x))⎟    2⋅⎜──(y(x))⎟    2⋅──(y(x))⎟                 ↪
# ↪  dx      ⎟   ⎜     ⎝dx      ⎠      ⎝dx      ⎠      dx      ⎟   d             ↪
# ↪ ─────────⎟ + ⎜──────────────── + ───────────── - ──────────⎟⋅─────(Y(y(x), x ↪
# ↪    x     ⎟   ⎜       6               y(x)            x     ⎟ dy(x)           ↪
# ↪          ⎠   ⎝    8⋅y (x)                                  ⎠                 ↪
#
# ↪      ⎛                                                                ⎛      ↪
# ↪      ⎜                                                                ⎜   4  ↪
# ↪      ⎜⎛   2                              2               ⎞            ⎜9⋅x ⋅ ↪
# ↪      ⎜⎜  d                d             d                ⎟ d          ⎜      ↪
# ↪ )) - ⎜⎜──────(X(y(x), x))⋅──(y(x)) + ────────(X(y(x), x))⎟⋅──(y(x)) + ⎜───── ↪
# ↪      ⎜⎜     2             dx         dx dy(x)            ⎟ dx         ⎜      ↪
# ↪      ⎝⎝dy(x)                                             ⎠            ⎝    8 ↪
#
# ↪           4               2             ⎞                                    ↪
# ↪ ⎛d       ⎞      ⎛d       ⎞      d       ⎟                                    ↪
# ↪ ⎜──(y(x))⎟    2⋅⎜──(y(x))⎟    2⋅──(y(x))⎟                      2             ↪
# ↪ ⎝dx      ⎠      ⎝dx      ⎠      dx      ⎟   d                 d              ↪
# ↪ ─────────── + ───────────── - ──────────⎟⋅─────(X(y(x), x)) + ───(X(y(x), x) ↪
# ↪   6               y(x)            x     ⎟ dy(x)                 2            ↪
# ↪ ⋅y (x)                                  ⎠                     dx             ↪
#
# ↪                                  ⎞                                           ↪
# ↪                                  ⎟                                           ↪
# ↪                  2               ⎟             2                             ↪
# ↪     d           d                ⎟ d          d                 d            ↪
# ↪ ) + ──(y(x))⋅────────(X(y(x), x))⎟⋅──(y(x)) + ───(Y(y(x), x)) + ──(y(x))⋅─── ↪
# ↪     dx       dy(x) dx            ⎟ dx           2               dx       dy( ↪
# ↪                                  ⎠            dx                             ↪
#
# ↪                  ⎞         ⎛                        ⎛               4        ↪
# ↪                  ⎟         ⎜                        ⎜   4 ⎛d       ⎞      ⎛d ↪
# ↪  2               ⎟         ⎜                  4     ⎜9⋅x ⋅⎜──(y(x))⎟    2⋅⎜─ ↪
# ↪ d                ⎟  6      ⎜      4 ⎛d       ⎞      ⎜     ⎝dx      ⎠      ⎝d ↪
# ↪ ─────(Y(y(x), x))⎟⋅y (x) + ⎜- 45⋅x ⋅⎜──(y(x))⎟  + 8⋅⎜──────────────── + ──── ↪
# ↪ x) dx            ⎟         ⎜        ⎝dx      ⎠      ⎜       6                ↪
# ↪                  ⎠         ⎝                        ⎝    8⋅y (x)             ↪
#
# ↪         2             ⎞                             ⎞                        ↪
# ↪        ⎞      d       ⎟                             ⎟                        ↪
# ↪ ─(y(x))⎟    2⋅──(y(x))⎟                            2⎟              ⎛         ↪
# ↪ x      ⎠      dx      ⎟  6          5    ⎛d       ⎞ ⎟              ⎜      5  ↪
# ↪ ───────── - ──────────⎟⋅y (x) - 16⋅y (x)⋅⎜──(y(x))⎟ ⎟⋅X(y(x), x) + ⎜- 36⋅x ⋅ ↪
# ↪ y(x)            x     ⎟                  ⎝dx      ⎠ ⎟              ⎝         ↪
# ↪                       ⎠                             ⎠                        ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪           3                                 ⎞                                ↪
# ↪ ⎛d       ⎞          5    d              6   ⎟ ⎛  ⎛d                  d       ↪
# ↪ ⎜──(y(x))⎟  - 32⋅x⋅y (x)⋅──(y(x)) + 16⋅y (x)⎟⋅⎜- ⎜──(X(y(x), x)) + ─────(X(y ↪
# ↪ ⎝dx      ⎠               dx                 ⎠ ⎝  ⎝dx               dy(x)     ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          d       ⎞ d          d                  d               d       ⎞   ↪
# ↪ (x), x))⋅──(y(x))⎟⋅──(y(x)) + ──(Y(y(x), x)) + ─────(Y(y(x), x))⋅──(y(x))⎟ + ↪
# ↪          dx      ⎠ dx         dx               dy(x)             dx      ⎠   ↪
# ↪                                                                              ↪
#
# ↪  ⎛     ⎛               4               2             ⎞                       ↪
# ↪  ⎜     ⎜   4 ⎛d       ⎞      ⎛d       ⎞      d       ⎟                       ↪
# ↪  ⎜     ⎜9⋅x ⋅⎜──(y(x))⎟    2⋅⎜──(y(x))⎟    2⋅──(y(x))⎟                       ↪
# ↪  ⎜     ⎜     ⎝dx      ⎠      ⎝dx      ⎠      dx      ⎟  5            4    ⎛d ↪
# ↪  ⎜48⋅x⋅⎜──────────────── + ───────────── - ──────────⎟⋅y (x) - 80⋅x⋅y (x)⋅⎜─ ↪
# ↪  ⎜     ⎜       6               y(x)            x     ⎟                    ⎝d ↪
# ↪  ⎝     ⎝    8⋅y (x)                                  ⎠                       ↪
#
# ↪                              ⎞
# ↪                              ⎟
# ↪         2                    ⎟
# ↪        ⎞        5    d       ⎟
# ↪ ─(y(x))⎟  + 96⋅y (x)⋅──(y(x))⎟⋅Y(y(x), x)
# ↪ x      ⎠             dx      ⎟
# ↪                              ⎠
# ipdb>  display(r.expand())
#                            4                                                   ↪
#     5            ⎛d       ⎞                                                    ↪
# 54⋅x ⋅Y(y(x), x)⋅⎜──(y(x))⎟                                   4                ↪
#                  ⎝dx      ⎠        5 d              ⎛d       ⎞       5   d     ↪
# ──────────────────────────── + 18⋅x ⋅──(X(y(x), x))⋅⎜──(y(x))⎟  + 9⋅x ⋅─────(X ↪
#             y(x)                     dx             ⎝dx      ⎠         dy(x)   ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                      5                                  3                    ↪
# ↪            ⎛d       ⎞        5 d              ⎛d       ⎞        5   d        ↪
# ↪ (y(x), x))⋅⎜──(y(x))⎟  - 36⋅x ⋅──(Y(y(x), x))⋅⎜──(y(x))⎟  - 27⋅x ⋅─────(Y(y( ↪
# ↪            ⎝dx      ⎠          dx             ⎝dx      ⎠          dy(x)      ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                   4                              4                           ↪
# ↪         ⎛d       ⎞        4            ⎛d       ⎞                     4    ⎛ ↪
# ↪ x), x))⋅⎜──(y(x))⎟  - 36⋅x ⋅X(y(x), x)⋅⎜──(y(x))⎟  + 16⋅x⋅Y(y(x), x)⋅y (x)⋅⎜ ↪
# ↪         ⎝dx      ⎠                     ⎝dx      ⎠                          ⎝ ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          2              2                                      2             ↪
# ↪ d       ⎞         6    d               d               6      d              ↪
# ↪ ──(y(x))⎟  - 8⋅x⋅y (x)⋅───(X(y(x), x))⋅──(y(x)) - 8⋅x⋅y (x)⋅──────(X(y(x), x ↪
# ↪ dx      ⎠                2             dx                        2           ↪
# ↪                        dx                                   dy(x)            ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪              3              2                             2                  ↪
# ↪    ⎛d       ⎞         6    d                      6      d                ⎛d ↪
# ↪ ))⋅⎜──(y(x))⎟  + 8⋅x⋅y (x)⋅───(Y(y(x), x)) + 8⋅x⋅y (x)⋅──────(Y(y(x), x))⋅⎜─ ↪
# ↪    ⎝dx      ⎠                2                              2             ⎝d ↪
# ↪                            dx                          dy(x)                 ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪         2                       2     2                                      ↪
# ↪        ⎞         6    ⎛d       ⎞     d                        6    ⎛d        ↪
# ↪ ─(y(x))⎟  - 8⋅x⋅y (x)⋅⎜──(y(x))⎟ ⋅────────(X(y(x), x)) - 8⋅x⋅y (x)⋅⎜──(y(x)) ↪
# ↪ x      ⎠              ⎝dx      ⎠  dy(x) dx                         ⎝dx       ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪  2     2                                         2                           ↪
# ↪ ⎞     d                        6    d           d                        6   ↪
# ↪ ⎟ ⋅────────(X(y(x), x)) + 8⋅x⋅y (x)⋅──(y(x))⋅────────(Y(y(x), x)) + 8⋅x⋅y (x ↪
# ↪ ⎠  dx dy(x)                         dx       dy(x) dx                        ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                2                                                         3   ↪
# ↪   d           d                         5      d               ⎛d       ⎞    ↪
# ↪ )⋅──(y(x))⋅────────(Y(y(x), x)) - 16⋅x⋅y (x)⋅─────(X(y(x), x))⋅⎜──(y(x))⎟  - ↪
# ↪   dx       dx dy(x)                          dy(x)             ⎝dx      ⎠    ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪        5    d              d                5      d               ⎛d        ↪
# ↪  32⋅x⋅y (x)⋅──(Y(y(x), x))⋅──(y(x)) - 16⋅x⋅y (x)⋅─────(Y(y(x), x))⋅⎜──(y(x)) ↪
# ↪             dx             dx                    dy(x)             ⎝dx       ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪  2                                                                           ↪
# ↪ ⎞        6    d              d              6      d               ⎛d        ↪
# ↪ ⎟  + 16⋅y (x)⋅──(X(y(x), x))⋅──(y(x)) + 32⋅y (x)⋅─────(X(y(x), x))⋅⎜──(y(x)) ↪
# ↪ ⎠             dx             dx                  dy(x)             ⎝dx       ↪
# ↪                                                                              ↪
#
# ↪
# ↪                                               6    d
# ↪  2                             16⋅X(y(x), x)⋅y (x)⋅──(y(x))
# ↪ ⎞        6    d                                    dx
# ↪ ⎟  + 16⋅y (x)⋅──(Y(y(x), x)) - ────────────────────────────
# ↪ ⎠             dx                            x
# ↪
# ipdb>  s
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(228)compute_overdetermined_system_of_infinitesimals()
#     226     r = r.xreplace({highest_term: sol})
#     227     coeffs = sorted(
# --> 228         extract_coeffs(r, dep, indep),
#     229         key=get_coeff_order,
#     230         reverse=True,
# ipdb>  s
# --Call--
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(129)extract_coeffs()
#     127     return acc
#     128
# --> 129 def extract_coeffs(expr, dep, indep):
#     130     def analyze_power(factor):
#     131         base = factor.as_base_exp()[0]
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(130)extract_coeffs()
#     128
#     129 def extract_coeffs(expr, dep, indep):
# --> 130     def analyze_power(factor):
#     131         base = factor.as_base_exp()[0]
#     132         if base.is_Derivative:
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(139)extract_coeffs()
#     137         #        return factor
#     138         return 1
# --> 139     args = expr.expand().args
#     140     all_i_need = set()
#     141     for term in args:
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(140)extract_coeffs()
#     138         return 1
#     139     args = expr.expand().args
# --> 140     all_i_need = set()
#     141     for term in args:
#     142         local_term = term.args
# ipdb>  n
# > /home/tapir/research-disk/delierium/src/delierium/Infinitesimals.py(141)extract_coeffs()
#     139     args = expr.expand().args
#     140     all_i_need = set()
# --> 141     for term in args:
#     142         local_term = term.args
#     143         f = 1

# %% [markdown]
# correct
