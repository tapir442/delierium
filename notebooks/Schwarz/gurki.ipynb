# %%
import sage.all
from delierium.matrix_order import Context, Mgrlex, Mgrevlex, Mlex
from delierium.JanetBasis import Janet_Basis, _Differential_Polynomial
from delierium.helpers import latexer
from IPython.display import Math

vars = var ("x y")
z = function("z")(x,y)
w = function("w")(x,y)
# ctx: items are in descending order"
ctx_grevlex_f = Context((w,z), (x,y), Mgrevlex)
ctx_grlex_f   = Context((w,z), (x,y), Mgrlex)
ctx_lex_f     = Context((w,z), (x,y), Mlex)

f1 = diff(w, y) + x*diff(z,y)/(2*y*(x**2+y)) - w/y
f2 = diff(z,x,y) + y*diff(w,y)/x + 2*y*diff(z, x)/x
f3 = diff(w, x,y) - 2*x*diff(z, x,2)/y - x*diff(w,x)/y**2
f4 = diff(w, x,y) + diff(z, x,y) + diff(w, y)/(2*y) - diff(w,x)/y + x* diff(z, y)/y - w/(2*y**2)
f5 = diff(w,y,y) + diff(z,x,y) - diff(w, y)/y + w/(y**2)
system_2_24 = [f4,f2,f1,f5,f3]
# %load_ext snakeviz
# %load_ext line_profiler
import time
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
start=time.time()
# %snakeviz jb=Janet_Basis(system_2_24, [z,w], [x,y], Mlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
#print("======================================")
#start=time.time()
#jb=Janet_Basis(system_2_24, [z,w], [x,y], Mgrlex)
#print(time.time() - start)
#for _ in jb.S:
#    print(_)
#print("======================================")
#start=time.time()
#jb=Janet_Basis(system_2_24, [z,w], [x,y], Mgrevlex)
#print(time.time() - start)
#for _ in jb.S:
#    print(_)    
#print("======================================")
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[2, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[2, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[2, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# []
# [_Dterm(coeff=-1/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# [_Dterm(coeff=y^(-2), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=x/y, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# [_Dterm(coeff=1/2/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# [_Dterm(coeff=-1/2/y^2, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# []
# [_Dterm(coeff=y/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# []
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[2, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[2, 0]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[2, 0]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[2, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[2, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), y, y), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[0, 2]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# []
# [_Dterm(coeff=1/4*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/(2*(x^2 + y)*y/x - 1), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# [_Dterm(coeff=1/4*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/(2*(x^2 + y)*y/x - 1), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c31af310>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# ...
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[1, 0]
# other.derivative=diff(z(x, y), y), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
#
# *** Profile stats marshalled to file '/tmp/tmp50i0nirg'.
# Embedding SnakeViz in this document...
# <function display at 0x7a793d8f23e0>
# <iframe id='snakeviz-e61b98f0-f345-11ee-91cd-9094e4f6e861' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-e61b98f0-f345-11ee-91cd-9094e4f6e861").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/%2Ftmp%2Ftmp50i0nirg")</script>
# 21.952701807022095
# diff(w(x, y), y) + (((x^2 + y)*y*(x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(2*(x^2 + y)/x^2 - 1/y^2 - 4)/((x^2 + y)*y))/x + ((2*(x^2 + y)*y/x - 1)*(x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) + (((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/x - 4*(x^2 + y)/x - (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/x - 4*y/x)/((2*(x^2 + y)*y/x - 1)*y) + 2*(x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/y + (x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y^2 - x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y))*((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*x*((x^2 + y)/x^2 - 2)/y + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y)^2 + ((x^2 + y)*x*(2*y*(2/x^2 - 1/y^3)/x + (4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*(x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - (x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y^2) + x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*y*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(x*(2*(x^2 + y)*y/x - 1)^2) + 2*x*((x^2 + y)/x^2 - 2)/y^2 + y*(2/x + 1/y^2)/(x*(2*(x^2 + y)*y/x - 1)) + (2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) + 1/y^2 - 2/(x*y))/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y) - 2*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (2/x + 1/y^2)/(2*(x^2 + y)*y/x - 1))*((4*x^2*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*x*(2*y - (x^2 + y)*y/x^2)*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)^2*y) + 2*(x^2 + y)*x*(8*y*(1/x - (x^2 + y)/x^3)/x - y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x^2 + 4*(x^2 + y)/x^2 - 8)/((2*(x^2 + y)*y/x - 1)*y) - 8*x*(1/x - (x^2 + y)/x^3)/y - (y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/(2*(x^2 + y)*y/x - 1) + 2*(x^2 + y)*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 4*((x^2 + y)/x^2 - 2)/y)/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y) - x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y))/(((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*x*((x^2 + y)/x^2 - 2)/y + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y) + (2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1))^2 - (((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/x - 4*(x^2 + y)/x - (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/x - 4*y/x)/((2*(x^2 + y)*y/x - 1)*y) + 2*(x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/y + (x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y^2 - x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y))*(4*x^2*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*x*(2*y - (x^2 + y)*y/x^2)*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)^2*y) + 2*(x^2 + y)*x*(8*y*(1/x - (x^2 + y)/x^3)/x - y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x^2 + 4*(x^2 + y)/x^2 - 8)/((2*(x^2 + y)*y/x - 1)*y) - 8 ...
# diff(w(x, y), x), [], []
# diff(z(x, y), y), [], []
# diff(z(x, y), x) + (-1/2*((x^2 + y)*y*(x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(2*(x^2 + y)/x^2 - 1/y^2 - 4)/((x^2 + y)*y))/x + ((2*(x^2 + y)*y/x - 1)*(x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) + (((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/x - 4*(x^2 + y)/x - (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/x - 4*y/x)/((2*(x^2 + y)*y/x - 1)*y) + 2*(x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/y + (x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y^2 - x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y))*((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*x*((x^2 + y)/x^2 - 2)/y + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y)^2 + ((x^2 + y)*x*(2*y*(2/x^2 - 1/y^3)/x + (4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*(x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - (x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y^2) + x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*y*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(x*(2*(x^2 + y)*y/x - 1)^2) + 2*x*((x^2 + y)/x^2 - 2)/y^2 + y*(2/x + 1/y^2)/(x*(2*(x^2 + y)*y/x - 1)) + (2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) + 1/y^2 - 2/(x*y))/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y) - 2*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (2/x + 1/y^2)/(2*(x^2 + y)*y/x - 1))*((4*x^2*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*x*(2*y - (x^2 + y)*y/x^2)*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)^2*y) + 2*(x^2 + y)*x*(8*y*(1/x - (x^2 + y)/x^3)/x - y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x^2 + 4*(x^2 + y)/x^2 - 8)/((2*(x^2 + y)*y/x - 1)*y) - 8*x*(1/x - (x^2 + y)/x^3)/y - (y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/(2*(x^2 + y)*y/x - 1) + 2*(x^2 + y)*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 4*((x^2 + y)/x^2 - 2)/y)/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y) - x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y))/(((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 2*x*((x^2 + y)/x^2 - 2)/y + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y) + (2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1))^2 - (((x^2 + y)*x*(y*(4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/x - 4*(x^2 + y)/x - (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/x - 4*y/x)/((2*(x^2 + y)*y/x - 1)*y) + 2*(x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/y + (x^2 + y)*x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/y^2 - x*(4*(x^2 + y)*y/x + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*y/x)/((2*(x^2 + y)*y/x - 1)*y))*(4*x^2*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*x*(2*y - (x^2 + y)*y/x^2)*(y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x - 4*(x^2 + y)/x)/((2*(x^2 + y)*y/x - 1)^2*y) + 2*(x^2 + y)*x*(8*y*(1/x - (x^2 + y)/x^3)/x - y*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/x^2 + 4*(x^2 + y)/x^2 - 8)/((2*(x^2 + y)*y/x - 1)*y ...

# %%
start=time.time()
jb=Janet_Basis(system_2_24, [z,w], [y,x], Mlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [z,w], [y,x], Mgrlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [z,w], [y,x], Mgrevlex)
print(time.time() - start)
for _ in jb.S:
    print(_)    
print("======================================")
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# []
# [_Dterm(coeff=-1/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c1fde010>)]
# [_Dterm(coeff=y^(-2), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c1fde010>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# []
# [_Dterm(coeff=y/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c1fde010>)]
# []
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=x/y, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c1fde010>)]
# [_Dterm(coeff=1/2/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c1fde010>)]
# [_Dterm(coeff=-1/2/y^2, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c1fde010>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# ...
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# [_Dterm(coeff=-1/2*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))*((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + 2*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (8*x*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - 4*(x^2 + y)*(16*x*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 16*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)^2/(2*(x^2 + y)*y/x - 1)^3 - 4*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)^2/(2*(x^2 + y)*y/x - 1)^3 + 4*x^3*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^3*y) + 2*x^2*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)^2*y) - 8*(x^2 + y)*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1)^2 - 16*(2*y - (x^2 + y)*y/x^2)*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1)^2 + x*(6*y/x^2 - 6*(x^2 + y)*y/x^4 - y/x^3)/((x^2 + y)*y) - 12*(y/x^2 - (x^2 + y)*y/x^4)/(2*(x^2 + y)*y/x - 1) - 4/(2*(x^2 + y)*y/x - 1) - 3*x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) - (4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y)) - 2*y*(4*x/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - (8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 4*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1))/x + 16*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + 4*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - 4*x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y) + y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x^2)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))) + 2*(4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)*x/((x^2 + y)^2*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))) + (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8* ...
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# 27.025397777557373
# diff(w(x, y), x), [], []
# diff(w(x, y), y) + (((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y) - (4*x*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 4*(x^2 + y)*((2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 4*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))) * w(x, y), [], []
# diff(z(x, y), x) + (1/2*(x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 1/2*(x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y) - (4*x*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 4*(x^2 + y)*((2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 4*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))) * w(x, y), [], []
# diff(z(x, y), y), [], []
# ======================================

# %%
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [y,x], Mlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [y,x], Mgrlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [y,x], Mgrevlex)
print(time.time() - start)
for _ in jb.S:
    print(_)    
print("======================================")
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y, y) == diff(w(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# []
# []
# []
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x, y), self.order=[1, 2]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=1/2/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# [_Dterm(coeff=1, derivative=diff(z(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# []
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x, y), self.order=[1, 2]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), x, x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x, y), self.order=[1, 2]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=-1/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# [_Dterm(coeff=1, derivative=diff(z(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# []
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y, y), other.order=[2, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x, y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y, y), other.order=[2, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, y, y), other.order=[2, 1]
# self.derivative==other.derivative=diff(w(x, y), y) == diff(z(x, y), x, y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), y) == diff(z(x, y), x, y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y, y), self.order=[2, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y, y), other.order=[2, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y, y), self.order=[2, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y, y), self.order=[2, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y, y), self.order=[2, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# []
# [_Dterm(coeff=y/x, derivative=diff(z(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# []
# []
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x, y), self.order=[1, 2]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x, y), self.order=[1, 2]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=1/2/y, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, x, y), other.order=[1, 2]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=y*(1/y - 1) + 1/2*x/y, derivative=diff(z(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# [_Dterm(coeff=-x, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=1, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=False
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# []
# [_Dterm(coeff=x/y, derivative=diff(z(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# []
# [_Dterm(coeff=2, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7a78c1e00590>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y, y), self.order=[2, 0]
# other.derivative=diff(z(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y, y) == diff(z(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y, y) == diff(z(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y, y), self.order=[2, 1]
# other.derivative=diff(z(x, y), y, y), other.order=[2, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y, y) == diff(z(x, y), y, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y, y) == diff(z(x, y), y, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# ...
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(w(x, y), x) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=w(x, y) == w(x, y)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# [_Dterm(coeff=-(x^2 + y)*y*(x/((x^2 + y)*y^2) + x/((x^2 + y)^2*y))/x - y/x, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c54123d0>)]
# [_Dterm(coeff=4*(x^2 + y)*y^2/x^2, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7a78c54123d0>)]
# [_Dterm(coeff=2*(x^2 + y)*y/x^2, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c54123d0>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, y), self.order=[1, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, y), other.order=[1, 1]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), y), other.order=[1, 0]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# [_Dterm(coeff=1/4*((x^2 + y)*y*(x/((x^2 + y)*y^2) + x/((x^2 + y)^2*y))/x + y/x)*x*(2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))/(x/((x^2 + y)*y) - 2) - 1/(x^2 + y) - x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)))/y, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7a78c54123d0>)]
# [_Dterm(coeff=-x*((x^2 + y)*y^2/x^2 - y*(2*(2*x/y^2 + 2*x^2/((x^2 + y)^2*y^2) + 4*x^2/((x^2 + y)^3*y) - 1/((x^2 + y)*y^2) - 1/((x^2 + y)^2*y))/(x/((x^2 + y)*y) - 2) - 2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))*(x/((x^2 + y)*y^2) + x/((x^2 + y)^2*y))/(x/((x^2 + y)*y) - 2)^2 - 1/(x^2 + y)^2 + x*(x/((x^2 + y)*y^2) + x/((x^2 + y)^2*y))/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)^2) - 2*x/((x^2 + y)*y^3*(x/((x^2 + y)*y) - 2)) - x/((x^2 + y)^2*y^2*(x/((x^2 + y)*y) - 2)))/(x*(2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))/(x/((x^2 + y)*y) - 2) - 1/(x^2 + y) - x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)))^2) - 1/(x*(2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))/(x/((x^2 + y)*y) - 2) - 1/(x^2 + y) - x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)))))*(2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))/(x/((x^2 + y)*y) - 2) - 1/(x^2 + y) - x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)))/y, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7a78c54123d0>)]
# [_Dterm(coeff=-1/2*x*((x^2 + y)*y/x^2 - (2*(2*x/y^2 + 2*x^2/((x^2 + y)^2*y^2) + 4*x^2/((x^2 + y)^3*y) - 1/((x^2 + y)*y^2) - 1/((x^2 + y)^2*y))/(x/((x^2 + y)*y) - 2) - 2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))*(x/((x^2 + y)*y^2) + x/((x^2 + y)^2*y))/(x/((x^2 + y)*y) - 2)^2 - 1/(x^2 + y)^2 + x*(x/((x^2 + y)*y^2) + x/((x^2 + y)^2*y))/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)^2) - 2*x/((x^2 + y)*y^3*(x/((x^2 + y)*y) - 2)) - x/((x^2 + y)^2*y^2*(x/((x^2 + y)*y) - 2)))/(x*(2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))/(x/((x^2 + y)*y) - 2) - 1/(x^2 + y) - x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)))^2))*(2*(2*x/y + 2*x^2/((x^2 + y)^2*y) - 1/((x^2 + y)*y))/(x/((x^2 + y)*y) - 2) - 1/(x^2 + y) - x/((x^2 + y)*y^2*(x/((x^2 + y)*y) - 2)))/y, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7a78c54123d0>)]
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x, x), self.order=[0, 2]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=diff(z(x, y), x, x) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(w(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(w(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=True
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=True
# self.order == other.order and expr_eq(self.coeff, other.coeff)=True
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(z(x, y), x, x), other.order=[0, 2]
# self.derivative==other.derivative=w(x, y) == diff(z(x, y), x, x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(z(x, y), x, x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=w(x, y), self.order=[0, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=w(x, y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=w(x, y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), x) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=True
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), x), self.order=[0, 1]
# other.derivative=w(x, y), other.order=[0, 0]
# self.derivative==other.derivative=diff(z(x, y), x) == w(x, y)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), x) == w(x, y)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(w(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(w(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(w(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# AAAAAAAAAAAAAAAAAAAAAAAAA
# self.derivative=diff(z(x, y), y), self.order=[1, 0]
# other.derivative=diff(z(x, y), x), other.order=[0, 1]
# self.derivative==other.derivative=diff(z(x, y), y) == diff(z(x, y), x)
# eq(self.derivative, other.derivative)=False
# self.order==other.order=False
# ......
# self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=diff(z(x, y), y) == diff(z(x, y), x)
# self.order == other.order and expr_eq(self.coeff, other.coeff)=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 print("======================================")
#       7 start=time.time()
# ----> 8 jb=Janet_Basis(system_2_24, [w,z], [y,x], Mgrlex)
#       9 print(time.time() - start)
#      10 for _ in jb.S:
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:817, in Janet_Basis.__init__(self, S, dependent, independent, sort_order)
#     811             old = self.S[:]
#     812  #           print("This is where we start")
#     813  #           self.show()
#     814 #            for _ in self.S:
#     815 #                _.Lder().show()
#     816             #set_trace()
# --> 817             self.S = Autoreduce(self.S, context)
#     818  #           print("after autoreduce")
#     819  #           self.show()
#     820 #            for _ in self.S:
#     821 #                display(Math(_.show(rich=True)))
#     822             self.S = CompleteSystem(self.S, context)
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:478, in Autoreduce(S, context)
#     476 have_reduced = False
#     477 for _r in r:
# --> 478     rnew = reduceS(_r, _p, context)
#     479     have_reduced = have_reduced or rnew != _r
#     480     if rnew:
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:367, in reduceS(e, S, context)
#     365 while reducing:
#     366     for dp in gen:
# --> 367         enew = reduce(e, dp, context)
#     368         # XXX check wheter we can replace "==" by 'is'
#     369         if enew == e:
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:466, in reduce(e1, e2, context)
#     464             return _Differential_Polynomial(e=0, context=e2.context, dterms=dterms)
#     465     return e1
# --> 466 while not bool((_e1 := _reduce_inner(e1, e2)) == e1):
#     467     e1 = _e1
#     468 return _e1
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:464, in reduce.<locals>._reduce_inner(e1, e2)
#     462                     subs.append(dt)
#     463         dterms = changed + subs
# --> 464         return _Differential_Polynomial(e=0, context=e2.context, dterms=dterms)
#     465 return e1
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:199, in _Differential_Polynomial.__init__(self, e, context, dterms)
#     197     else:
#     198         pass
# --> 199 self.p.sort(reverse=True)
#     200 self.normalize()
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:126, in _Dterm.__lt__(self, other)
#     113 """
#     114 >>> x,y,z = var("x y z")
#     115 >>> from delierium.matrix_order import Mlex
#    (...)
#     123 True
#     124 """
#     125 # XXX context.gt still a bad place
# --> 126 return not (self is other) and not eq(self, other) and \
#     127     self.context.gt(other.comparison_vector, self.comparison_vector)
#
# File ~/research-disk/delierium/src/delierium/helpers.py:33, in eq(d1, d2)
#      31 if d1.__class__ != d2.__class__:
#      32     return False
# ---> 33 return bool(d1 == d2)
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:139, in _Dterm.__eq__(self, other)
#     137 print(f"{self.derivative == other.derivative and expr_eq(self.coeff, other.coeff)=}")
#     138 print(f"{self.order == other.order and expr_eq(self.coeff, other.coeff)=}")
# --> 139 return eq(self.derivative, other.derivative) and \
#     140     expr_eq(self.coeff, other.coeff)
#
# File src/cysignals/signals.pyx:310, in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [x,y], Mlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("looks strange as len(S) == 3 instead of 4")    
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [x,y], Mgrlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
print("======================================")
start=time.time()
jb=Janet_Basis(system_2_24, [w,z], [x,y], Mgrevlex)
print(time.time() - start)
for _ in jb.S:
    print(_)
