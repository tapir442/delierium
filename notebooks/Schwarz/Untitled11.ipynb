# %%
import sympy

# %%
from sympy import symbols
from sympy.core.sympify import sympify
x, y = symbols('x y')

# %%
gugu=sympify(-2*(x^2 + y)*((x^2 + y)*y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - x*(2*(x^2 + y)/x^2 - 1/y^2 - 4)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x - ((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))*((2*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 - (2/x + 1/y^2)/(2*(x^2 + y)*y/x - 1) + (2*(x^2 + y)*(((x^2 + y)/x + y/x)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - (2/x^2 - 1/y^3)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y^2) - x*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 2*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y^2) + 2/((2*(x^2 + y)*y/x - 1)*y) + 1/((x^2 + y)*x*y)) + 2*y*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(x*(2*(x^2 + y)*y/x - 1)^2) - (4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - y*(2/x + 1/y^2)/(x*(2*(x^2 + y)*y/x - 1)) + 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y) - (2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y^2)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))) - ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)*(8*(x^2 + y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/((x^2 + y)*y) - 4/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y))/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))^2) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)^2*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y) - (4*x*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 4*(x^2 + y)*((2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 4*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))^2 - (2*((x^2 + y)/x + y/x)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*(2/x^2 - 1/y^3)/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - (8*x*(((x^2 + y)/x + y/x)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - (2/x^2 - 1/y^3)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y^2) - x*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 2*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y^2) + 2/((2*(x^2 + y)*y/x - 1)*y) + 1/((x^2 + y)*x*y)) - 4*(x^2 + y)*(4*(2*y - (x^2 + y)*y/x^2)*((x^2 + y)/x + y/x)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^3 + (4*(x^2 + y)/x^2 + 1/y^2 - 8)*((x^2 + y)/x^2 + y/x^2 - 2)/(2*(x^2 + y)*y/x - 1)^2 - 8*((x^2 + y)/x + y/x)*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1)^2 - 2*(2*y - (x^2 + y)*y/x^2)*(2/x^2 - 1/y^3)/(2*(x^2 + y)*y/x - 1)^2 + 8*x*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - 16*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^3*y) - 4*(x^2 + y)*((x^2 + y)/x^2 + y/x^2 - 2)/((2*(x^2 + y)*y/x - 1)^2*y) - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y^2) - 4*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^3*y) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y^2) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)^2*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y^2) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y^2) + 4*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y^2) + ((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) + 2/((x^2 + y)^2*y) - 4/(x^3*(2*(x^2 + y)*y/x - 1)) + 1/((x^2 + y)*x^2*y)) - 2*y*(((x^2 + y)/x + y/x)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - (2/x^2 - 1/y^3)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - 2*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y^2) + 2/((2*(x^2 + y)*y/x - 1)*y))/x + ((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x + 4*(2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 8*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 16*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 8*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 16*x/((2*(x^2 + y)*y/x - 1)*y) - 16*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + 4*((x^2 + y)/x^2 - 2)/((x^2 + y)*y))/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))) + (4*x*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 4*(x^2 + y)*((2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 4*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x)*(8*(x^2 + y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/((x^2 + y)*y) - 4/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y))/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))^2) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y^2) + 4/((2*(x^2 + y)*y/x - 1)*y) - (4*x*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 4*(x^2 + y)*((2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 4*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x)/((x^2 + y)^2*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)))) + (4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)))) + (2*(x^2 + y)/x - 1/y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y) - (4*x*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 4*(x^2 + y)*((2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 4*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/((2*(x^2 + y)*y/x - 1)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))))*y/(((x^2 + y)*y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 + 1/y)/((x^2 + y)*y))/x - (4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (8*(x^2 + y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4/(2*(x^2 + y)*y/x - 1) - (4*x*(8*(x^2 + y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/((x^2 + y)*y) - 4/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y)) + 2*(x^2 + y)*(16*x*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 - 32*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^3 - 8*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^3 - 16*((x^2 + y)/x + y/x)*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1)^2 - 2*(2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/((x^2 + y)^2*y) - 8*(x^2 + y)*((x^2 + y)/x^2 + y/x^2 - 2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x^2 + y/x^2 - 2)/(2*(x^2 + y)*y/x - 1)^2 - x*(4/x - 4*(x^2 + y)/x^3 - 1/x^2 - 4*y/x^3)/((x^2 + y)*y) + 8*(1/x - (x^2 + y)/x^3 - y/x^3)/(2*(x^2 + y)*y/x - 1) + 8*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y^2) + 4*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^3*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y^2) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)^2*y) - (2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/((x^2 + y)*y) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y^2) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y)) - y*(8*(x^2 + y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4/(2*(x^2 + y)*y/x - 1))/x - 16*x/(2*(x^2 + y)*y/x - 1) + 16*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 4*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 4*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + (4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x - 2*x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) + 16*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) + 2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))) + (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)*(8*(x^2 + y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/((x^2 + y)*y) - 4/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y))/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))^2) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)^2*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)))) + (4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))*(2*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 - (2/x + 1/y^2)/(2*(x^2 + y)*y/x - 1) + (2*(x^2 + y)*(((x^2 + y)/x + y/x)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - (2/x^2 - 1/y^3)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)*((x^2 + y)/x + y/x)/((2*(x^2 + y)*y/x - 1)^2*y) - x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y^2) - x*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 2*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y^2) + 2/((2*(x^2 + y)*y/x - 1)*y) + 1/((x^2 + y)*x*y)) + 2*y*(2*(x^2 + y)/x - 1/y)*((x^2 + y)/x + y/x)/(x*(2*(x^2 + y)*y/x - 1)^2) - (4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - y*(2/x + 1/y^2)/(x*(2*(x^2 + y)*y/x - 1)) + 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y) - (2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y^2)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))) - ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)*(8*(x^2 + y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*((x^2 + y)/x + y/x)/(2*(x^2 + y)*y/x - 1)^2 + (4*(x^2 + y)/x^2 + 4*y/x^2 - 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - x*(2*(x^2 + y)/x^2 + 1/x + 2*y/x^2 - 4)/((x^2 + y)*y) - 4/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y^2) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y))/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))^2) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)^2*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))^2 + ((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y) - (4*x*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) - 4*(x^2 + y)*((2*y - (x^2 + y)*y/x^2)*(4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1)^2 - 2*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - 4*(1/x - (x^2 + y)/x^3)/(2*(x^2 + y)*y/x - 1) + 2*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 4*x/((2*(x^2 + y)*y/x - 1)*y) - 4*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/((2*(x^2 + y)*y/x - 1)^2*y) + ((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)))))*((2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1) + ((x^2 + y)*((4*(x^2 + y)/x^2 + 1/y^2 - 8)/(2*(x^2 + y)*y/x - 1) - 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((2*(x^2 + y)*y/x - 1)*y)) + y*(2*(x^2 + y)/x - 1/y)/(x*(2*(x^2 + y)*y/x - 1)) - 1/y)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y))))/(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - (4*x*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(2*(x^2 + y)*y/x - 1) - 8*(x^2 + y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 - 2*(8*y - 4*(x^2 + y)*y/x^2 - 1/y)*(2*y - (x^2 + y)*y/x^2)/(2*(x^2 + y)*y/x - 1)^2 + 2*x^2*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)^2*y) + x*(4*y/x - 4*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) - 8*(y/x - (x^2 + y)*y/x^3)/(2*(x^2 + y)*y/x - 1) - (4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1))/x)/((x^2 + y)*(4*(x^2 + y)/(2*(x^2 + y)*y/x - 1) + (8*y - 4*(x^2 + y)*y/x^2 - 1/y)/(2*(x^2 + y)*y/x - 1) - x*(4*y - 2*(x^2 + y)*y/x^2 - y/x)/((x^2 + y)*y)))) + (2*(x^2 + y)/x - 1/y)/(2*(x^2 + y)*y/x - 1))*x) - 2*(x^2 + y)/x)

# %%
gugu.__class__
# Out:
# <class 'sympy.core.add.Add'>
