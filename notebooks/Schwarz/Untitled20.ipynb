# %%
import sage.all
from delierium.matrix_order import Context, Mgrlex, Mgrevlex, Mlex
from delierium.JanetBasis import Janet_Basis, _Differential_Polynomial
from delierium.helpers import latexer
from IPython.display import Math

vars = var ("x y")
z = function("z")(x,y)
w = function("w")(x,y)
# ctx: items are in descending order"
ctx_grevlex_f = Context((w,z), (x,y), Mgrevlex)
ctx_grlex_f   = Context((w,z), (x,y), Mgrlex)
ctx_lex_f     = Context((w,z), (x,y), Mlex)

f1 = diff(w, y) + x*diff(z,y)/(2*y*(x**2+y)) - w/y
f2 = diff(z,x,y) + y*diff(w,y)/x + 2*y*diff(z, x)/x
f3 = diff(w, x,y) - 2*x*diff(z, x,2)/y - x*diff(w,x)/y**2
f4 = diff(w, x,y) + diff(z, x,y) + diff(w, y)/(2*y) - diff(w,x)/y + x* diff(z, y)/y - w/(2*y**2)
f5 = diff(w,y,y) + diff(z,x,y) - diff(w, y)/y + w/(y**2)
system_2_24 = [f4,f2,f1,f5,f3]
# %load_ext snakeviz
# %load_ext line_profiler
import time

# %%
 ordering = Mgrevlex
start=time.time()
jb=Janet_Basis(system_2_24, [z, w], [x,y], ordering)
jb.show(rich=False, short=True)
print(time.time() - start)
print("="*150)
# Out:
# This is where we start
# [diff(z(x, y), y), diff(w(x, y), y), w(x, y)]
# [diff(z(x, y), x, y), diff(z(x, y), x), diff(w(x, y), y)]
# [diff(z(x, y), x, y), diff(w(x, y), y, y), diff(w(x, y), y), w(x, y)]
# [diff(z(x, y), x, y), diff(w(x, y), x, y), diff(z(x, y), y), diff(w(x, y), x), diff(w(x, y), y), w(x, y)]
# [diff(z(x, y), x, x), diff(w(x, y), x, y), diff(w(x, y), x)]
# BBBBBBBBBBBBBBBBBBBBBB
# f=1, g=diff(z(x, y), y), variables=([x],)
# fprime=0
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=0, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(z(x, y), x, y)
# f=2*(x^2 + y)*y/x, g=diff(w(x, y), y), variables=([x],)
# fprime=4*y - 2*(x^2 + y)*y/x^2
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=4*y - 2*(x^2 + y)*y/x^2, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x, y)
# e1=y/x
# e2=4.0*y - 2.0*(x^2 + y)*y/x^2
# locals()={'e1': y/x, 'e2': 4.0*y - 2.0*(x^2 + y)*y/x^2, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [512, 971], 'r': {y: 512, x: 971}}
# f=-2*(x^2 + y)/x, g=w(x, y), variables=([x],)
# fprime=2*(x^2 + y)/x^2 - 4
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=2*(x^2 + y)/x^2 - 4, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x)
# _=_Dterm(coeff=2*y/x, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-2*(x^2 + y)*y/x, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-2*(x^2 + y)/x^2 + 4, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=2*(x^2 + y)/x, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/(x^2 + y), derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# e1=-1/(x^2 + y)
# e2=-1/(x^2 + y)
# locals()={'e1': -1/(x^2 + y), 'e2': -1/(x^2 + y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [161, 714], 'r': {y: 161, x: 714}}
# e1=-1/y
# e2=-1/y
# locals()={'e1': -1/y, 'e2': -1/y, 'l1': (y,), 'l2': (y,), 'l': [y], 'substituted': False, 'rlist': [203], 'r': {y: 203}}
# e1=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)
# e2=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)
# locals()={'e1': -1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), 'e2': -1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [883, 154], 'r': {y: 883, x: 154}}
# e1=x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y)
# e2=x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y)
# locals()={'e1': x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y), 'e2': x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [215, 717], 'r': {y: 215, x: 717}}
# _=_Dterm(coeff=1, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/(x^2 + y), derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# BBBBBBBBBBBBBBBBBBBBBB
# f=1, g=diff(z(x, y), y), variables=([x],)
# fprime=0
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=0, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(z(x, y), x, y)
# f=2*(x^2 + y)*y/x, g=diff(w(x, y), y), variables=([x],)
# fprime=4*y - 2*(x^2 + y)*y/x^2
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=4*y - 2*(x^2 + y)*y/x^2, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x, y)
# f=-2*(x^2 + y)/x, g=w(x, y), variables=([x],)
# fprime=2*(x^2 + y)/x^2 - 4
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=2*(x^2 + y)/x^2 - 4, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x)
# _=_Dterm(coeff=1.0, derivative=diff(w(x, y), y, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-2*(x^2 + y)*y/x, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=2*(x^2 + y)/x, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# BBBBBBBBBBBBBBBBBBBBBB
# f=1, g=diff(z(x, y), y), variables=([x],)
# fprime=0
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=0, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(z(x, y), x, y)
# f=2*(x^2 + y)*y/x, g=diff(w(x, y), y), variables=([x],)
# fprime=4*y - 2*(x^2 + y)*y/x^2
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=4*y - 2*(x^2 + y)*y/x^2, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x, y)
# f=-2*(x^2 + y)/x, g=w(x, y), variables=([x],)
# fprime=2*(x^2 + y)/x^2 - 4
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=2*(x^2 + y)/x^2 - 4, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x)
# _=_Dterm(coeff=-2.0*(x^2 + y)*y/x + 1.0, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=x/y, derivative=diff(z(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=2.0*(x^2 + y)/x - 1/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-4.0*y + 2.0*(x^2 + y)*y/x^2 + 1/2/y, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-2.0*(x^2 + y)/x^2 - 1/2/y^2 + 4.0, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# BBBBBBBBBBBBBBBBBBBBBB
# e1=x/((-2.0*(x^2 + y)*y/x + 1.0)*y)
# e2=x/((-2.0*(x^2 + y)*y/x + 1.0)*y)
# locals()={'e1': x/((-2.0*(x^2 + y)*y/x + 1.0)*y), 'e2': x/((-2.0*(x^2 + y)*y/x + 1.0)*y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [961, 583], 'r': {y: 961, x: 583}}
# e1=-1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)
# e2=2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0)
# locals()={'e1': -1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), 'e2': 2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [461, 400], 'r': {y: 461, x: 400}}
# e1=-1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0)
# e2=-2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)
# locals()={'e1': -1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0), 'e2': -2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [848, 201], 'r': {y: 848, x: 201}}
# _=_Dterm(coeff=1, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*y/x, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# e1=-1/2*y/x
# e2=-1/2*y/x
# locals()={'e1': -1/2*y/x, 'e2': -1/2*y/x, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [420, 991], 'r': {y: 420, x: 991}}
# e1=1/2/y
# e2=1/2/y
# locals()={'e1': 1/2/y, 'e2': 1/2/y, 'l1': (y,), 'l2': (y,), 'l': [y], 'substituted': False, 'rlist': [257], 'r': {y: 257}}
# _=_Dterm(coeff=1, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/(x^2 + y), derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*y/x, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/(x^2 + y), derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# BBBBBBBBBBBBBBBBBBBBBB
# e1=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)
# e2=-2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)
# locals()={'e1': -1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), 'e2': -2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [801, 895], 'r': {y: 801, x: 895}}
# e1=x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y)
# e2=-1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)
# locals()={'e1': x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y), 'e2': -1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [392, 306], 'r': {y: 392, x: 306}}
# _=_Dterm(coeff=-1/(x^2 + y), derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# e1=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)
# e2=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)
# locals()={'e1': (x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), 'e2': (x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [284, 433], 'r': {y: 284, x: 433}}
# e1=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))
# e2=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))
# locals()={'e1': -1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), 'e2': -1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [531, 741], 'r': {y: 531, x: 741}}
# e1=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))
# e2=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))
# locals()={'e1': -1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), 'e2': -1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [425, 307], 'r': {y: 425, x: 307}}
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# BBBBBBBBBBBBBBBBBBBBBB
# e1=-1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y)
# e2=-2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)
# locals()={'e1': -1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y), 'e2': -2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [539, 185], 'r': {y: 539, x: 185}}
# e1=-1/2*x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y)
# e2=-1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)
# locals()={'e1': -1/2*x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y), 'e2': -1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [103, 822], 'r': {y: 103, x: 822}}
# _=_Dterm(coeff=-0.5*x/((x^2 + y)*y), derivative=diff(w(x, y), y, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y) - 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1.0, derivative=diff(w(x, y), y, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=2.0*(x^2 + y)*y*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)/x, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1.0*(x^2 + y)*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1.0*(x^2 + y)*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# e1=2.0*(x^2 + y)*y*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)/x
# e2=2.0*(x^2 + y)*y*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)/x
# locals()={'e1': 2.0*(x^2 + y)*y*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)/x, 'e2': 2.0*(x^2 + y)*y*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)/x, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [973, 852], 'r': {y: 973, x: 852}}
# e1=-1.0*(x^2 + y)*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y))/x
# e2=-1.0*(x^2 + y)*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y))/x
# locals()={'e1': -1.0*(x^2 + y)*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y))/x, 'e2': -1.0*(x^2 + y)*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y))/x, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [778, 349], 'r': {y: 778, x: 349}}
# e1=-1.0*(x^2 + y)*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x
# e2=-1.0*(x^2 + y)*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x
# locals()={'e1': -1.0*(x^2 + y)*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, 'e2': -1.0*(x^2 + y)*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [872, 238], 'r': {y: 872, x: 238}}
# _=_Dterm(coeff=1.0, derivative=diff(w(x, y), y, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=2.0*(x^2 + y)*y*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)/x, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1.0*(x^2 + y)*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 - 1/y)/((x^2 + y)*y))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1.0*(x^2 + y)*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-2.0*(x^2 + y)/x^2 + 1/y^2 + 4.0)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*y/x, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# BBBBBBBBBBBBBBBBBBBBBB
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# e1=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y
# e2=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y
# locals()={'e1': 1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, 'e2': 1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [816, 640], 'r': {y: 816, x: 640}}
# e1=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x
# e2=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x
# locals()={'e1': -1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, 'e2': -1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [423, 238], 'r': {y: 423, x: 238}}
# e1=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x
# e2=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x
# locals()={'e1': -1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, 'e2': -1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [692, 154], 'r': {y: 692, x: 154}}
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# BBBBBBBBBBBBBBBBBBBBBB
# f=1, g=diff(z(x, y), x), variables=([x],)
# fprime=0
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=0, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(z(x, y), x, x)
# f=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), g=diff(w(x, y), x), variables=([x],)
# fprime=2*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) - (x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0))
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=2*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) - (x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0)), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x, x)
# e1=1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y
# e2=2*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) - (x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0))
# locals()={'e1': 1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, 'e2': 2*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) - (x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0)), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [105, 617], 'r': {y: 105, x: 617}}
# f=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), g=diff(w(x, y), y), variables=([x],)
# fprime=-x*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) - 1/2*(x^2 + y)*(8*x/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x^2*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)^2*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - x*(4.0*y/x - 4.0*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) + (-8.0*y/x + 8.0*(x^2 + y)*y/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - (-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=-x*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) - 1/2*(x^2 + y)*(8*x/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x^2*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)^2*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - x*(4.0*y/x - 4.0*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) + (-8.0*y/x + 8.0*(x^2 + y)*y/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - (-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x, y)
# e1=-1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x
# e2=-x*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) - 1/2*(x^2 + y)*(8*x/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x^2*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)^2*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - x*(4.0*y/x - 4.0*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) + (-8.0*y/x + 8.0*(x^2 + y)*y/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - (-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))
# locals()={'e1': -1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, 'e2': -x*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) - 1/2*(x^2 + y)*(8*x/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x^2*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)^2*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - x*(4.0*y/x - 4.0*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) + (-8.0*y/x + 8.0*(x^2 + y)*y/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - (-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [839, 202], 'r': {y: 839, x: 202}}
# f=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), g=w(x, y), variables=([x],)
# fprime=-x*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) + 1/2*(x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0)^2 + 4*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - (8.0/x - 8.0*(x^2 + y)/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 8*x/((-2.0*(x^2 + y)*y/x + 1.0)*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/((-2.0*(x^2 + y)*y/x + 1.0)^2*y) - 2*((x^2 + y)/x^2 - 2)/((x^2 + y)*y))
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# d1=_Dterm(coeff=-x*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) + 1/2*(x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0)^2 + 4*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - (8.0/x - 8.0*(x^2 + y)/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 8*x/((-2.0*(x^2 + y)*y/x + 1.0)*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/((-2.0*(x^2 + y)*y/x + 1.0)^2*y) - 2*((x^2 + y)/x^2 - 2)/((x^2 + y)*y)), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# gprime=diff(w(x, y), x)
# e1=-1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x
# e2=-x*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) + 1/2*(x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0)^2 + 4*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - (8.0/x - 8.0*(x^2 + y)/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 8*x/((-2.0*(x^2 + y)*y/x + 1.0)*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/((-2.0*(x^2 + y)*y/x + 1.0)^2*y) - 2*((x^2 + y)/x^2 - 2)/((x^2 + y)*y))
# locals()={'e1': -1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, 'e2': -x*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) + 1/2*(x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0)^2 + 4*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - (8.0/x - 8.0*(x^2 + y)/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 8*x/((-2.0*(x^2 + y)*y/x + 1.0)*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/((-2.0*(x^2 + y)*y/x + 1.0)^2*y) - 2*((x^2 + y)/x^2 - 2)/((x^2 + y)*y)), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [322, 825], 'r': {y: 322, x: 825}}
# e1=-2*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) + (x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y
# e2=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))
# locals()={'e1': -2*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) + (x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, 'e2': -1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [652, 694], 'r': {y: 652, x: 694}}
# _=_Dterm(coeff=-2*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) + (x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) + 1/2*y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) + 1/2/y, derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=x*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) + 1/2*(x^2 + y)*(8*x/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x^2*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)^2*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - x*(4.0*y/x - 4.0*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) + (-8.0*y/x + 8.0*(x^2 + y)*y/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - (-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) - 1/4*y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x, derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=x*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) - 1/2*(x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0)^2 + 4*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - (8.0/x - 8.0*(x^2 + y)/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 8*x/((-2.0*(x^2 + y)*y/x + 1.0)*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/((-2.0*(x^2 + y)*y/x + 1.0)^2*y) - 2*((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - 1/4*y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x, derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), derivative=diff(w(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(z(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=(x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1, derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# e1=(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)
# e2=(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)
# locals()={'e1': (2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), 'e2': (2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [685, 303], 'r': {y: 685, x: 303}}
# e1=-2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)
# e2=-2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)
# locals()={'e1': -2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), 'e2': -2*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) - 1/2*(8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [281, 772], 'r': {y: 281, x: 772}}
# e1=-1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)
# e2=-1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)
# locals()={'e1': -1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), 'e2': -1/2*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [899, 700], 'r': {y: 899, x: 700}}
# _=_Dterm(coeff=1, derivative=diff(w(x, y), x, x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/2*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))/((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), derivative=diff(w(x, y), x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=1/2*(4*x*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y) - 2*(x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (-2.0*(x^2 + y)/x^2 + 4.0)/(-2.0*(x^2 + y)*y/x + 1.0)) - (x^2 + y)*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) - y*(2.0*(x^2 + y)/x - 1/y)/(x*(-2.0*(x^2 + y)*y/x + 1.0)) - 1/y)/((x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)), derivative=diff(w(x, y), x), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*(4*x*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) + 2*(x^2 + y)*(8*x/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x^2*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)^2*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/(-2.0*(x^2 + y)*y/x + 1.0)^2 - x*(4.0*y/x - 4.0*(x^2 + y)*y/x^3 - y/x^2)/((x^2 + y)*y) + (-8.0*y/x + 8.0*(x^2 + y)*y/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - (-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y)) - y*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0))/x)/((x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)), derivative=diff(w(x, y), y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# _=_Dterm(coeff=-1/4*(4*x*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) + 2*x*((x^2 + y)/x^2 - 2)/((x^2 + y)*y) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y)) - 2*(x^2 + y)*((-4.0*y + 2.0*(x^2 + y)*y/x^2)*(4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0)^2 + 4*x^2*((x^2 + y)/x^2 - 2)/((x^2 + y)^2*y) - (8.0/x - 8.0*(x^2 + y)/x^3)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*x*(1/x - (x^2 + y)/x^3)/((x^2 + y)*y) + 8*x/((-2.0*(x^2 + y)*y/x + 1.0)*y) - 4*(x^2 + y)*(-4.0*y + 2.0*(x^2 + y)*y/x^2)/((-2.0*(x^2 + y)*y/x + 1.0)^2*y) - 2*((x^2 + y)/x^2 - 2)/((x^2 + y)*y)) - y*((4.0*(x^2 + y)/x^2 + 1/y^2 - 8.0)/(-2.0*(x^2 + y)*y/x + 1.0) - 4*(x^2 + y)/((-2.0*(x^2 + y)*y/x + 1.0)*y))/x)/((x^2 + y)*((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)), derivative=w(x, y), context=<delierium.matrix_order.Context object at 0x7eaa83e76e50>)
# e1=-1/2*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))/((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)
# e2=-1/2*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))/((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y)
# locals()={'e1': -1/2*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))/((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), 'e2': -1/2*(4*(x^2 + y)/(-2.0*(x^2 + y)*y/x + 1.0) + (8.0*y - 4.0*(x^2 + y)*y/x^2 - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) - x*(-4.0*y + 2.0*(x^2 + y)*y/x^2 + y/x)/((x^2 + y)*y))/((2.0*(x^2 + y)/x - 1/y)/(-2.0*(x^2 + y)*y/x + 1.0) + 1/y), 'l1': (x, y), 'l2': (x, y), 'l': [y, x], 'substituted': False, 'rlist': [141, 940], 'r': {y: 141, x: 940}}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 ordering = Mgrevlex
#       2 start=time.time()
# ----> 3 jb=Janet_Basis(system_2_24, [z, w], [x,y], ordering)
#       4 jb.show(rich=False, short=True)
#       5 print(time.time() - start)
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:892, in Janet_Basis.__init__(self, S, dependent, independent, sort_order)
#     889 print("This is where we start")
#     890 self.show(rich=False, short=True)
# --> 892 self.S = Autoreduce(self.S, context)
#     893 print("after autoreduce")
#     894 self.show(rich=False, short=True)
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:525, in Autoreduce(S, context)
#     523 have_reduced = False
#     524 for _r in r:
# --> 525     rnew = reduceS(_r, _p, context)
#     526     have_reduced = have_reduced or rnew != _r
#     527     if rnew:
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:428, in reduceS(e, S, context)
#     426 while reducing:
#     427     for dp in gen:
# --> 428         enew = reduce(e, dp, context)
#     429         # XXX check wheter we can replace "==" by 'is'
#     430         if enew == e:
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:512, in reduce(e1, e2, context)
#     511 def reduce(e1: _Differential_Polynomial, e2: _Differential_Polynomial, context: Context) -> _Differential_Polynomial:
# --> 512     while not (new_e1 := _reduce_inner(e1, e2, context)) == e1:
#     513         e1 = new_e1
#     514     return new_e1
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:355, in _Differential_Polynomial.__eq__(self, other)
#     353 if len(self.p) != len(other.p):
#     354     return False
# --> 355 return all(_[0] == _[1] for _ in zip(self.p, other.p))
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:355, in <genexpr>(.0)
#     353 if len(self.p) != len(other.p):
#     354     return False
# --> 355 return all(_[0] == _[1] for _ in zip(self.p, other.p))
#
# File ~/research-disk/delierium/src/delierium/JanetBasis.py:136, in _Dterm.__eq__(self, other)
#     132 @profile
#     133 def __eq__(self, other):
#     134     return self is other or \
#     135         (self.comparison_vector == other.comparison_vector and \
# --> 136          expr_eq(self.coeff, other.coeff))
#
# File ~/research-disk/delierium/src/delierium/helpers.py:67, in expr_eq(e1, e2)
#      65 print(f"{locals()=}")
#      66 try:
# ---> 67     ev1 = e1.subs(r)
#      68     substituted = True
#      69 except AttributeError:
#
# File ~/mambaforge/envs/sage/lib/python3.11/site-packages/sage/symbolic/expression.pyx:5899, in sage.symbolic.expression.Expression.substitute (build/cythonized/sage/symbolic/expression.cpp:76782)()
#    5897     smap.insert(make_pair((<Expression>self.coerce_in(k))._gobj,
#    5898                           (<Expression>self.coerce_in(v))._gobj))
# -> 5899 res = self._gobj.subs_map(smap, 0)
#    5900 return new_Expression_from_GEx(self._parent, res)
#    5901
#
# ValueError: power::eval(): division by zero
