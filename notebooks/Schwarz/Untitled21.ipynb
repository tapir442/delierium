# %%
from sympy import *
x, y= symbols("x y")

# %%
e1=0.25*(4.0*y*(y*(x/y^2 - 1.0/y)/x - 1.0/y)*(0.25*(2.0*x*(1.0*(x/y^2 + 1.0*x^2/((x^2 + y)^2*y^2) + 2.0*x^2/((x^2 + y)^3*y) - 0.5/((x^2 + y)*y^2) - 0.5/((x^2 + y)^2*y))/(-0.5*x/((x^2 + y)*y) + 1.0) + 1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))*(0.5*x/((x^2 + y)*y^2) + 0.5*x/((x^2 + y)^2*y))/(-0.5*x/((x^2 + y)*y) + 1.0)^2 + 0.5/(x^2 + y)^2 - 0.25*x*(0.5*x/((x^2 + y)*y^2) + 0.5*x/((x^2 + y)^2*y))/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)^2) - 0.5*x/((x^2 + y)*y^3*(-0.5*x/((x^2 + y)*y) + 1.0)) - 0.25*x/((x^2 + y)^2*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y^2 + 1/(x^2 + y)^2)/(y*(y*(x/y^2 - 1.0/y)/x - 1.0/y)) + 0.25*(2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 1/(x^2 + y))*(y*(2*x/y^3 - 1.0/y^2)/x - (x/y^2 - 1.0/y)/x - 1.0/y^2)/(y*(y*(x/y^2 - 1.0/y)/x - 1.0/y)^2) - 0.5*(2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 1/(x^2 + y))/(y^2*(y*(x/y^2 - 1.0/y)/x - 1.0/y)))/(2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 1/(x^2 + y)) + 1.0/y)*(2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 1/(x^2 + y))/(y*(y*(x/y^2 - 1.0/y)/x - 1.0/y)*(-0.25*(2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 1/(x^2 + y))/(-0.5*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y + 1/4/(x^2 + y)) - 1.0)*((-0.0625*(2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 1/(x^2 + y))*(2.0*x*(1.0*(x/y^2 + 1.0*x^2/((x^2 + y)^2*y^2) + 2.0*x^2/((x^2 + y)^3*y) - 0.5/((x^2 + y)*y^2) - 0.5/((x^2 + y)^2*y))/(-0.5*x/((x^2 + y)*y) + 1.0) + 1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))*(0.5*x/((x^2 + y)*y^2) + 0.5*x/((x^2 + y)^2*y))/(-0.5*x/((x^2 + y)*y) + 1.0)^2 + 0.5/(x^2 + y)^2 - 0.25*x*(0.5*x/((x^2 + y)*y^2) + 0.5*x/((x^2 + y)^2*y))/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)^2) - 0.5*x/((x^2 + y)*y^3*(-0.5*x/((x^2 + y)*y) + 1.0)) - 0.25*x/((x^2 + y)^2*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y^2 + 1/(x^2 + y)^2)/(-0.5*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y + 1/4/(x^2 + y))^2 - 0.25*(2.0*x*(1.0*(x/y^2 + 1.0*x^2/((x^2 + y)^2*y^2) + 2.0*x^2/((x^2 + y)^3*y) - 0.5/((x^2 + y)*y^2) - 0.5/((x^2 + y)^2*y))/(-0.5*x/((x^2 + y)*y) + 1.0) + 1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))*(0.5*x/((x^2 + y)*y^2) + 0.5*x/((x^2 + y)^2*y))/(-0.5*x/((x^2 + y)*y) + 1.0)^2 + 0.5/(x^2 + y)^2 - 0.25*x*(0.5*x/((x^2 + y)*y^2) + 0.5*x/((x^2 + y)^2*y))/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)^2) - 0.5*x/((x^2 + y)*y^3*(-0.5*x/((x^2 + y)*y) + 1.0)) - 0.25*x/((x^2 + y)^2*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y^2 + 1/(x^2 + y)^2)/(-0.5*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y + 1/4/(x^2 + y)) + 1.0/y)/(-0.25*(2.0*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y - 1/(x^2 + y))/(-0.5*x*(-1.0*(x/y + 1.0*x^2/((x^2 + y)^2*y) - 0.5/((x^2 + y)*y))/(-0.5*x/((x^2 + y)*y) + 1.0) - 0.5/(x^2 + y) + 0.25*x/((x^2 + y)*y^2*(-0.5*x/((x^2 + y)*y) + 1.0)))/y + 1/4/(x^2 + y)) - 1.0) + 1.0/y))

# %%
e2=e1+x

# %%
dir(e1)
# Out:
# ['__abs__',
#  '__add__',
#  '__annotations__',
#  '__class__',
#  '__complex__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__sympy__',
#  '__truediv__',
#  '__trunc__',
#  '_add_handler',
#  '_args',
#  '_args_type',
#  '_assumptions',
#  '_combine_inverse',
#  '_compare_pretty',
# ...

# %%
help(e1.ratsimp)
# Out:
# Help on method ratsimp in module sympy.core.expr:
#
# ratsimp() method of sympy.core.mul.Mul instance
#     See the ratsimp function in sympy.simplify

# %%
e1.subs({x:2, y:3})

# %%
e1

# %%
e1.__class__
# Out:
# <class 'sympy.core.mul.Mul'>
