# %%
# %display latex
from pprint import pprint

# %%
f = function('f')
y = function('y')
var("x")
f = diff(y(x) , x, x, x) + (2+1/x)*diff(y(x), x) - 4*y(x)/((x - 4)**2 + x - 3)
f
# Out:
# (1/x + 2)*diff(y(x), x) - 4*y(x)/((x - 4)^2 + x - 3) + diff(y(x), x, x, x)

# %%
from sage.symbolic.expression_conversions import ExpressionTreeWalker
from sage.symbolic.operators import FDerivativeOperator 
from operator import mul
def determine_poles (L, y, x, order = 0):
    # XXX can we determine the order ourselves?
    denom = sum([L.coefficient(diff(y(x), x, i)) for i in range (order+1)]).denominator()
    if x not in denom.variables():
        # constant
        return []
    sol = solve(denom, x)
    print (sol)

# %%
# this is wrong as the last 'x' should be a 1
determine_poles(f, y, x, 3)
# Out:
# [
# x == -1/2*I*sqrt(3) + 7/2,
# x == 1/2*I*sqrt(3) + 7/2,
# x == 0
# ]

# %%
c = f.coefficients(diff(y(x), x));c
# Out:
# [[-4*y(x)/x^2, 0], [(x^2 + log(x))*(1/x + 2) + 1, 1]]

# %%
foo = function('foo')
g   = function ('g')
f = 1+foo(x).diff(x)
s = ExpressionTreeWalker(f)
print(s.derivative(f, f.operator()))
bool(s.derivative(f, f.operator()) == f)
g = x
s = ExpressionTreeWalker(g)
print(bool(s.derivative(g, g.operator()) == g))




f
# Out:
# diff(foo(x), x) + 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-7f13d5563076> in <module>
#       7 g = x
#       8 s = ExpressionTreeWalker(g)
# ----> 9 print(bool(s.derivative(g, g.operator()) == g))
#      10
#      11
#
# ~/anaconda3/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in derivative(self, ex, operator)
#    2140             True
#    2141         """
# -> 2142         return operator(*map(self, ex.operands()))
#    2143
#    2144     def tuple(self, ex):
#
# TypeError: 'NoneType' object is not callable

# %%
pprint(dir(g))
# Out:
# ['Order',
#  'WZ_certificate',
#  '__abs__',
#  '__add__',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__complex__',
#  '__copy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getmetaclass__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pari__',
#  '__pos__',
#  '__pow__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
# ...

# %%
pprint(dir(f))
# Out:
# ['Order',
#  'WZ_certificate',
#  '__abs__',
#  '__add__',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__complex__',
#  '__copy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getmetaclass__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pari__',
#  '__pos__',
#  '__pow__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
# ...
